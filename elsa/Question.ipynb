# %% [markdown]
# Hi, I've got a question re ElementTree
#
# I managed to run the code below for an XML with the contents below (got the sample XML from the ElementTree tutorial)

# %%
#code:
import xml.etree.ElementTree as ET
tree = ET.parse(r'C:\Users\elsar\OneDrive\Desktop\country_data.xml')
root = tree.getroot()

for rank in root.iter('rank'):
    print(rank.text)

# få ut subelement som är child of country name, dvs grandchild of rooten
for year in root.iter('year'):
    print(year.text)

# få ut elementet som är child av rooten
for country in root.findall('country'):
    print(country.get('name'))

# %% [markdown]
# output:
# C:\Users\elsar\AppData\Local\Programs\Python\Python37\python.exe C:/Users/elsar/PycharmProjects/test/test1.py
# 1
# 4
# 68
# 2008
# 2011
# 2011
# Liechtenstein
# Singapore
# Panama
#
# Process finished with exit code 0

# %% [markdown]
# file:
# ![image.png](attachment:image.png)

# %% [markdown]
# I tried some different ways to replace the code above, to make it work for a sample part of the uniprot file

# %%
import xml.etree.ElementTree as ET
tree = ET.parse("sample_from_uniprot.xml")
root = tree.getroot()

for name in root.iter("name"):
    print(name.text)

for name in root.findall('name'):
    print(name.get("name"))

# %% [markdown]
# output:
#     C:\Users\elsar\AppData\Local\Programs\Python\Python37\python.exe C:/Users/elsar/PycharmProjects/test/make_dictionary_uniprot.py
#
# Process finished with exit code 0

# %% [markdown]
# First part of file (it is a valid file according to XML ValidatorBuddy)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Questions:
# * How can I make it return 001R_FRG3G?
