# %% [markdown]
# # Spacy PhraseMatcher

# %%
import spacy
import scispacy

# %%
from spacy.matcher import PhraseMatcher

# %%
path = 'C:\\Users\\Sonja\\Anaconda3\\envs\\scispacy\\Lib\\site-packages\\en_core_sci_lg\\en_core_sci_lg-0.2.4'

# %%
nlp = spacy.load(path)

# %%
abstract = """2019nCOV, also named SARS COV 2, causes COVID 19, also referred to as Wuhan pneumonia."""

# %%
covid19_terms = []
with open('corona_disease.txt','r') as disease:
    for line in disease:
        x = disease.readline().strip()
        covid19_terms.append(x)
    print(covid19_terms)
disease.close()
# Out:
# ['covid 19', 'coronavirus disease 2019', 'coronavirus disease19', '2019 novel coronavirus respiratory syndrome', 'wurs', 'severe acute respiratory syndrome type 2', 'sars2', '2019 sars', 'wuhan infection', 'seafood market infection', 'covid 19 virus infection', 'sarscov2 2019 infection', '2019novel sarscov2 infection', '2019 novel sarscov2 infection', 'hcov 19 infection', 'sars cov 2 infection', '2019 sars cov 2 infection', '2019new sars cov 2 infection', '2019 new sars cov 2 infection', 'new coronavirus 2019 infection', 'new corona virus infection', '2019 new corona virus infection', 'novel coronavirus 2019 infection', 'novel corona virus infection', '2019 novel corona virus infection', 'wuhan virus 2019 infection', '2019novel wuhan virus infection', '2019 novel wuhan virus infection', 'wuhan pneumonia virus infection', '2019 wuhan pneumonia virus infection', '2019new wuhan pneumonia virus infection', '2019 new wuhan pneumonia virus infection', 'wuhan coronavirus 2019 infection', '2019novel wuhan coronavirus infection', '2019 novel wuhan coronavirus infection', 'wuhan corona virus infection', '2019 wuhan corona virus infection', '2019new wuhan corona virus infection', '2019 new wuhan corona virus infection', 'wuhancoronavirus 2019 infection', '2019novel wuhancoronavirus infection', '2019 novel wuhancoronavirus infection', 'wuhancorona virus infection', '2019 wuhancorona virus infection', '2019new wuhancorona virus infection', '2019 new wuhancorona virus infection', 'wuhan seafood market pneumonia virus 2019 infection', '2019novel wuhan seafood market pneumonia virus infection', '2019 novel wuhan seafood market pneumonia virus infection', 'wuhan seafood market virus infection', '2019 wuhan seafood market virus infection', '2019new wuhan seafood market virus infection', '2019 new wuhan seafood market virus infection', 'seafood market virus 2019 infection', '2019novel seafood market virus infection', '2019 novel seafood market virus infection', 'seafood market coronavirus infection', '2019 seafood market coronavirus infection', '2019new seafood market coronavirus infection', '2019 new seafood market coronavirus infection', 'seafood market corona virus 2019 infection', '2019novel seafood market corona virus infection', '2019 novel seafood market corona virus infection', 'chinese coronavirus infection', '2019 chinese coronavirus infection', '2019new chinese coronavirus infection', '2019 new chinese coronavirus infection', 'chinese corona virus 2019 infection', '2019novel chinese corona virus infection', '2019 novel chinese corona virus infection', '2019 corona virus infection', '2019ncov infection', '2019 human corona virus infection', 'human coronavirus 2019 infection', 'sars coronavirus 2 infection', '2019 sars coronavirus 2 infection', '2019new sars coronavirus 2 infection', '2019 new sars coronavirus 2 infection', 'sars corona virus 2 2019 infection', '
ars coronavirus2', '2019 sars coronavirus2', '2019new sars coronavirus2', '2019 new sars coronavirus2', 'sars corona virus2 2019', '2019novel sars corona virus2', '2019 novel sars corona virus2', 'virus responsible for covid19', 'severe acute respiratory syndrome coronavirus 2', '2019 severe acute respiratory syndrome coronavirus 2', '2019new severe acute respiratory syndrome coronavirus 2', '2019 new severe acute respiratory syndrome coronavirus 2', 'severe acute respiratory syndrome corona virus 2 2019', '2019novel severe acute respiratory syndrome corona virus 2', '2019 novel severe acute respiratory syndrome corona virus 2', 'severe acute respiratory syndrome coronavirus2', '2019 severe acute respiratory syndrome coronavirus2', '2019new severe acute respiratory syndrome coronavirus2', '2019 new severe acute respiratory syndrome coronavirus2', 'severe acute respiratory syndrome corona virus2 2019', '2019novel severe acute respiratory syndrome corona virus2', '2019 novel severe acute respiratory syndrome corona virus2', 'severe acute respiratory syndromerelated coronavirus 2', '2019 severe acute respiratory syndromerelated coronavirus 2', '2019new severe acute respiratory syndromerelated coronavirus 2', '2019 new severe acute respiratory syndromerelated coronavirus 2', 'severe acute respiratory syndromerelated corona virus 2 2019', '2019novel severe acute respiratory syndromerelated corona virus 2', '2019 novel severe acute respiratory syndromerelated corona virus 2', 'severe acute respiratory syndromerelated coronavirus2', '2019 severe acute respiratory syndromerelated coronavirus2', '2019new severe acute respiratory syndromerelated coronavirus2', '2019 new severe acute respiratory syndromerelated coronavirus2', 'severe acute respiratory syndromerelated corona virus2 2019', '2019novel severe acute respiratory syndromerelated corona virus2', '2019 novel severe acute respiratory syndromerelated corona virus2', 'NCBI ...

# %%
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
# Only run nlp.make_doc to speed things up
sarscov2patterns = [nlp.make_doc(text) for text in sarscov2_terms]
covid19patterns = [nlp.make_doc(text) for text in covid19_terms]
matcher.add("covid19", None, *covid19patterns)
matcher.add("sarscov2", None, *sarscov2patterns) #the first argument is the class

# %%
doc = nlp(abstract)
matches = matcher(doc)
entities = []
for match_id, start, end in matches:
    span = doc[start:end]
    class_id = nlp.vocab.strings[match_id]
    print(span.text, span.start_char, span.end_char, class_id)
    ent = {"start": span.start_char, "end": span.end_char, "label": class_id}
    entities.append(ent)
print(entities)
# Out:
# 2019nCOV 0 8 sarscov2
# SARS COV 2 21 31 sarscov2
# COVID 19 40 48 covid19
# Wuhan pneumonia 70 85 covid19
# [{'start': 0, 'end': 8, 'label': 'sarscov2'}, {'start': 21, 'end': 31, 'label': 'sarscov2'}, {'start': 40, 'end': 48, 'label': 'covid19'}, {'start': 70, 'end': 85, 'label': 'covid19'}]

# %% [markdown]
# Overlapping entities need to be removed before visualization

# %%
from spacy import displacy

# %%
test = [{"text": abstract,
       "ents": entities,
       "title": None}]
html = displacy.render(test, style="ent", manual=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019nCOV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">sarscov2</span>
# </mark>
# , also named
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SARS COV 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">sarscov2</span>
# </mark>
# , causes
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID 19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">covid19</span>
# </mark>
# , also referred to as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wuhan pneumonia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">covid19</span>
# </mark>
# .</div>
