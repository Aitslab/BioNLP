# %% [markdown]
# # Spacy PhraseMatcher

# %%
import spacy
import scispacy

# %%
from spacy.matcher import PhraseMatcher

# %%
path = 'C:\\Users\\Sonja\\Anaconda3\\envs\\scispacy\\Lib\\site-packages\\en_core_sci_lg\\en_core_sci_lg-0.2.4'

# %%
nlp = spacy.load(path)

# %%
abstract = """2019nCOV, also named SARS COV 2, causes COVID 19, also referred to as Wuhan pneumonia."""

# %%
covid19_terms = []
with open('corona_disease.txt','r') as disease:
    for line in disease:
        x = line.strip()
        covid19_terms.append(x)
    print(covid19_terms)
# Out:
# ['covid19', 'covid 19', 'ncp', 'coronavirus disease 2019', 'corona virus disease 2019', 'coronavirus disease19', 'corona virus disease19', '2019 novel coronavirus respiratory syndrome', '2019 novel corona virus respiratory syndrome', 'wurs', 'seafood market pneumonia', 'severe acute respiratory syndrome type 2', 'sars 2', 'sars2', 'sars 2019', '2019 sars', 'severe acute respiratory syndrome 2019', 'wuhan infection', 'hubei infection', 'seafood market infection', 'covid19 virus infection', 'covid 19 virus infection', 'sarscov2 infection', 'sarscov2 2019 infection', '2019 sarscov2 infection', '2019novel sarscov2 infection', '2019new sarscov2 infection', '2019 novel sarscov2 infection', '2019 new sarscov2 infection', 'hcov 19 infection', 'hcov19 infection', 'sars cov 2 infection', 'sars cov 2 2019 infection', '2019 sars cov 2 infection', '2019novel sars cov 2 infection', '2019new sars cov 2 infection', '2019 novel sars cov 2 infection', '2019 new sars cov 2 infection', 'new coronavirus infection', 'new coronavirus 2019 infection', '2019 new coronavirus infection', 'new corona virus infection', 'new corona virus 2019 infection', '2019 new corona virus infection', 'novel coronavirus infection', 'novel coronavirus 2019 infection', '2019 novel coronavirus infection', 'novel corona virus infection', 'novel corona virus 2019 infection', '2019 novel corona virus infection', 'wuhan virus infection', 'wuhan virus 2019 infection', '2019 wuhan virus infection', '2019novel wuhan virus infection', '2019new wuhan virus infection', '2019 novel wuhan virus infection', '2019 new wuhan virus infection', 'wuhan pneumonia virus infection', 'wuhan pneumonia virus 2019 infection', '2019 wuhan pneumonia virus infection', '2019novel wuhan pneumonia virus infection', '2019new wuhan pneumonia virus infection', '2019 novel wuhan pneumonia virus infection', '2019 new wuhan pneumonia virus infection', 'wuhan coronavirus infection', 'wuhan coronavirus 2019 infection', '2019 wuhan coronavirus infection', '2019novel wuhan coronavirus infection', '2019new wuhan coronavirus infection', '2019 novel wuhan coronavirus infection', '2019 new wuhan coronavirus infection', 'wuhan corona virus infection', 'wuhan corona virus 2019 infection', '2019 wuhan corona virus infection', '2019novel wuhan corona virus infection', '2019new wuhan corona virus infection', '2019 novel wuhan corona virus infection', '2019 new wuhan corona virus infection', 'wuhancoronavirus infection', 'wuhancoronavirus 2019 infection', '2019 wuhancoronavirus infection', '2019novel wuhancoronavirus infection', '2019new wuhancoronavirus infection', '2019 novel wuhancoronavirus infection', '2019 new wuhancoronavirus infection', 'wuhancorona virus infection', 'wuhancorona virus 2019 infection', '2019 wuhancorona virus infection', '2019novel wuhancorona virus inf
ia virus', '2019 novel wuhan seafood market pneumonia virus', '2019 new wuhan seafood market pneumonia virus', 'wuhan seafood market virus', 'wuhan seafood market virus 2019', '2019 wuhan seafood market virus', '2019novel wuhan seafood market virus', '2019new wuhan seafood market virus', '2019 novel wuhan seafood market virus', '2019 new wuhan seafood market virus', 'seafood market virus', 'seafood market virus 2019', '2019 seafood market virus', '2019novel seafood market virus', '2019new seafood market virus', '2019 novel seafood market virus', '2019 new seafood market virus', 'seafood market coronavirus', 'seafood market coronavirus 2019', '2019 seafood market coronavirus', '2019novel seafood market coronavirus', '2019new seafood market coronavirus', '2019 novel seafood market coronavirus', '2019 new seafood market coronavirus', 'seafood market corona virus', 'seafood market corona virus 2019', '2019 seafood market corona virus', '2019novel seafood market corona virus', '2019new seafood market corona virus', '2019 novel seafood market corona virus', '2019 new seafood market corona virus', 'chinese coronavirus', 'chinese coronavirus 2019', '2019 chinese coronavirus', '2019novel chinese coronavirus', '2019new chinese coronavirus', '2019 novel chinese coronavirus', '2019 new chinese coronavirus', 'chinese corona virus', 'chinese corona virus 2019', '2019 chinese corona virus', '2019novel chinese corona virus', '2019new chinese corona virus', '2019 novel chinese corona virus', '2019 new chinese corona virus', '2019 corona virus', '2019 coronavirus', '2019ncov', '2019 ncov', '2019 human corona virus', '2019 human coronavirus', 'human coronavirus 2019', 'human corona virus 2019', 'sars coronavirus 2', 'sars coronavirus 2 2019', '2019 sars coronavirus 2', '2019novel sars coronavirus 2', '2019new sars coronavirus 2', '2019 novel sars coronavirus 2', '2019 new sars coronavirus 2', 'sars corona virus 2', 'sars corona virus 2 2019', '2019 sars corona virus 2', '2019novel sars coro ...

# %%
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
# Only run nlp.make_doc to speed things up
sarscov2patterns = [nlp.make_doc(text) for text in sarscov2_terms]
covid19patterns = [nlp.make_doc(text) for text in covid19_terms]
matcher.add("covid19", None, *covid19patterns)
matcher.add("sarscov2", None, *sarscov2patterns) #the first argument is the class

# %%
doc = nlp(abstract)
matches = matcher(doc)
entities = []
for match_id, start, end in matches:
    span = doc[start:end]
    class_id = nlp.vocab.strings[match_id]
    print(span.text, span.start_char, span.end_char, class_id)
    ent = {"start": span.start_char, "end": span.end_char, "label": class_id}
    entities.append(ent)
print(entities)
# Out:
# 2019nCOV 0 8 sarscov2
# SARS COV 2 21 31 sarscov2
# COVID 19 40 48 covid19
# Wuhan pneumonia 70 85 covid19
# [{'start': 0, 'end': 8, 'label': 'sarscov2'}, {'start': 21, 'end': 31, 'label': 'sarscov2'}, {'start': 40, 'end': 48, 'label': 'covid19'}, {'start': 70, 'end': 85, 'label': 'covid19'}]

# %% [markdown]
# Overlapping entities need to be removed before visualization

# %%
from spacy import displacy

# %%
test = [{"text": abstract,
       "ents": entities,
       "title": None}]
html = displacy.render(test, style="ent", manual=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019nCOV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">sarscov2</span>
# </mark>
# , also named
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SARS COV 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">sarscov2</span>
# </mark>
# , causes
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID 19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">covid19</span>
# </mark>
# , also referred to as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wuhan pneumonia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">covid19</span>
# </mark>
# .</div>
