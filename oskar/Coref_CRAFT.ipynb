# %% [markdown]
# ### System Installation
# Installing the coref tool from mandarjoshi90 along with tensorflow.

# %%
# !nvidia-smi --query-gpu=gpu_name,driver_version,memory.total --format=csv
# Out:
# name, driver_version, memory.total [MiB]
# Tesla T4, 460.32.03, 15109 MiB

# %%
! git clone https://github.com/mandarjoshi90/coref.git
# Out:
# Cloning into 'coref'...
# remote: Enumerating objects: 734, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 734 (delta 2), reused 0 (delta 0), pack-reused 728
# Receiving objects: 100% (734/734), 4.17 MiB | 20.55 MiB/s, done.
# Resolving deltas: 100% (441/441), done.

# %%
# %cd coref
! sed 's/MarkupSafe==1.0/MarkupSafe==1.1.1/; s/scikit-learn==0.19.1/scikit-learn==0.21/; s/scipy==1.0.0/scipy==1.6.2/' < requirements.txt > tmp
! mv tmp requirements.txt

! sed 's/.D.GLIBCXX.USE.CXX11.ABI.0//' < setup_all.sh  > tmp
! mv tmp setup_all.sh 
! chmod u+x setup_all.sh
# Out:
# /content/coref

# %%
# %tensorflow_version 2.x
! pip uninstall -y tensorflow
! pip install -r requirements.txt --log install-log.txt -q
! ./setup_all.sh
# Out:
# Uninstalling tensorflow-2.4.1:
#   Successfully uninstalled tensorflow-2.4.1
#      |████████████████████████████████| 102kB 11.1MB/s
#      |████████████████████████████████| 1.2MB 40.9MB/s
#      |████████████████████████████████| 163kB 53.5MB/s
#      |████████████████████████████████| 6.6MB 27.9MB/s
#      |████████████████████████████████| 552kB 53.4MB/s
#      |████████████████████████████████| 61kB 9.2MB/s
#      |████████████████████████████████| 2.2MB 35.9MB/s
#      |████████████████████████████████| 266kB 55.5MB/s
#      |████████████████████████████████| 890kB 38.1MB/s
#      |████████████████████████████████| 133kB 57.1MB/s
#      |████████████████████████████████| 153kB 59.8MB/s
#      |████████████████████████████████| 51kB 7.2MB/s
#      |████████████████████████████████| 51kB 7.3MB/s
#      |████████████████████████████████| 92kB 13.6MB/s
#      |████████████████████████████████| 20.3MB 1.4MB/s
#      |████████████████████████████████| 2.1MB 37.2MB/s
#      |████████████████████████████████| 1.2MB 42.1MB/s
#      |████████████████████████████████| 430kB 55.6MB/s
#      |████████████████████████████████| 71kB 10.9MB/s
#      |████████████████████████████████| 256kB 59.4MB/s
#      |████████████████████████████████| 71kB 11.2MB/s
#      |████████████████████████████████| 61kB 8.3MB/s
#      |████████████████████████████████| 194kB 55.3MB/s
#      |████████████████████████████████| 512kB 48.3MB/s
#      |████████████████████████████████| 61kB 9.8MB/s
#      |████████████████████████████████| 6.7MB 48.9MB/s
#      |████████████████████████████████| 27.4MB 118kB/s
#      |████████████████████████████████| 3.2MB 42.4MB/s
#      |████████████████████████████████| 491kB 52.8MB/s
#      |████████████████████████████████| 377.1MB 48kB/s
#      |████████████████████████████████| 748.9MB 19kB/s
#      |████████████████████████████████| 8.8MB 28.7MB/s
#      |████████████████████████████████| 327kB 58.9MB/s
#      |████████████████████████████████| 51kB 8.4MB/s
#      |████████████████████████████████| 256kB 57.3MB/s
#      |████████████████████████████████| 4.1MB 48.7MB/s
#   Building wheel for absl-py (setup.py) ... done
#   Building wheel for gast (setup.py) ... done
#   Building wheel for h5py (setup.py) ... done
#   Building wheel for html5lib (setup.py) ... done
#   Building wheel for JPype1 (setup.py) ... done
#   Building wheel for mmh3 (setup.py) ... done
#   Building wheel for msgpack-python (setup.py) ... done
#   Building wheel for psycopg2 (setup.py) ... done
#   Building wheel for pycparser (setup.py) ... done
#   Building wheel for pyhocon (setup.py) ... done
#   Building wheel for wrapt (setup.py) ... done
#   Building wheel for PyYAML (setup.py) ... done
# ERROR: fancyimpute 0.4.3 requires tensorflow, which is not installed.
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.2.0 which is incompatible.
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow-metadata 0.30.0 has requirement absl-py<0.13,>=0.9, but you'll have absl-py 0.7.1 which is incompatible.
# ERROR: pyasn1-modules 0.2.8 has requirement pyasn1<0.5.0,>=0.4.6, but you'll have pyasn1 0.4.2 which is incompatible.
# ERROR: pandas 1.1.5 has requirement python-dateutil>=2.7.3, but you'll have python-dateutil 2.6.1 which is incompatible.
# ERROR: googleapis-common-protos 1.53.0 has requirement protobuf>=3.12.0, but you'll have protobuf 3.9.1 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement astor~=0.8.1, but you'll have astor 0.8.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement six~=1.15.0, but you'll have six 1.12.0 which is incompatible.
# ERROR: google-api-python-client 1.12.8 has requirement six<2dev,>=1.13.0, but you'll have six 1.12.0 which is incompatible.
# ERROR: google-api-core 1.26.3 has requirement protobuf>=3.12.0, but you'll have protobuf 3.9.1 which is incompatible.
# ERROR: google-api-core 1.26.3 has requirement six>=1.13.0, but you'll have six 1.12.0 which is incompatible.
# ERROR: flask 1.1.2 has requirement Jinja2>=2.10.1, but you'll have jinja2 2.10 which is incompatible.
# ERROR: flask 1.1.2 has requirement Werkzeug>=0.15, but you'll have werkzeug 0.14.1 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement python-dateutil>=2.8.0, but you'll have python-dateutil 2.6.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: bokeh 2.3.2 has requirement pillow>=7.1.0, but you'll have pillow 6.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ### Specifying Input
#
# Input and Model

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
genre = "nw"
# The Ontonotes data for training the model contains text from several sources
# of very different styles. You need to specify the most suitable one out of:
# "bc": broadcast conversation
# "bn": broadcast news
# "mz": magazine
# "nw": newswire
# "pt": Bible text
# "tc": telephone conversation
# "wb": web data

model_name = "spanbert_base"
# The fine-tuned model to use. Options are:
# bert_base
# spanbert_base
# bert_large
# spanbert_large

# %%
import os
os.environ['data_dir'] = "./data"
os.environ['CHOSEN_MODEL'] = model_name

# %% [markdown]
# Downloading the selected model.

# %%
! ./download_pretrained.sh $CHOSEN_MODEL
# Out:
# Downloading spanbert_base
# --2021-05-16 17:24:36--  http://nlp.cs.washington.edu/pair2vec/spanbert_base.tar.gz
# Resolving nlp.cs.washington.edu (nlp.cs.washington.edu)... 128.208.3.120, 2607:4000:200:12::78
# Connecting to nlp.cs.washington.edu (nlp.cs.washington.edu)|128.208.3.120|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1633726311 (1.5G) [application/x-gzip]
# Saving to: ‘./data/spanbert_base.tar.gz’
#
# spanbert_base.tar.g  57%[==========>         ] 896.47M  18.6MB/s    eta 38s

# %% [markdown]
# Process the data to be in the required input format:

# %%
from bert import tokenization
import json


def tokenize(data):
  data = {
      'doc_key': genre,
      'sentences': [["[CLS]"]],
      'speakers': [["[SPL]"]],
      'clusters': [],
      'sentence_map': [0],
      'subtoken_map': [0],
  }

  # Determine Max Segment
  max_segment = None
  for line in open('experiments.conf'):
      if line.startswith(model_name):
          max_segment = True
      elif line.strip().startswith("max_segment_len"):
          if max_segment:
              max_segment = int(line.strip().split()[-1])
              break

  tokenizer = tokenization.FullTokenizer(vocab_file="cased_config_vocab/vocab.txt", do_lower_case=False)
  subtoken_num = 0
  for sent_num, line in enumerate(text):
      raw_tokens = line.split()
      tokens = tokenizer.tokenize(line)
      if len(tokens) + len(data['sentences'][-1]) >= max_segment:
          data['sentences'][-1].append("[SEP]")
          data['sentences'].append(["[CLS]"])
          data['speakers'][-1].append("[SPL]")
          data['speakers'].append(["[SPL]"])
          data['sentence_map'].append(sent_num - 1)
          data['subtoken_map'].append(subtoken_num - 1)
          data['sentence_map'].append(sent_num)
          data['subtoken_map'].append(subtoken_num)

      ctoken = raw_tokens[0]
      cpos = 0
      for token in tokens:
          data['sentences'][-1].append(token)
          data['speakers'][-1].append("-")
          data['sentence_map'].append(sent_num)
          data['subtoken_map'].append(subtoken_num)
          
          if token.startswith("##"):
              token = token[2:]
          if len(ctoken) == len(token):
              subtoken_num += 1
              cpos += 1
              if cpos < len(raw_tokens):
                  ctoken = raw_tokens[cpos]
          else:
              ctoken = ctoken[len(token):]

  data['sentences'][-1].append("[SEP]")
  data['speakers'][-1].append("[SPL]")
  data['sentence_map'].append(sent_num - 1)
  data['subtoken_map'].append(subtoken_num - 1)

  return data

def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %% [markdown]
# ## Prediction & Evaluation

# %%
# %mkdir ./data/in
# %mkdir ./data/out

# %%
import subprocess

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
filename = "/content/gdrive/MyDrive/CRAFT-txt/dev/17194222.txt"



text = []
data = []

with open(filename) as f_in:
  
  paragraphs = [line for line in f_in.read().split('\n') if line]
  
  for paragraph in paragraphs:
    sentences = tokenizer.tokenize(paragraph)
    text.extend(sentences)
                
chs = list(chunks(text, 100))

N = len(chs)

for i in range(0, N):
  
  text = chs[i]
  data.append(tokenize(text))

  file1 = "./data/in/" + str(i) + ".json"
  file2 = "./data/out/_" + str(i) + ".json"

  with open(file1, 'w') as out:
    json.dump(data[i], out, sort_keys=True)

  subprocess.call(['python', 'predict.py', 'spanbert_base', file1, file2])

# %%
import subprocess
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

for file in [f for f in os.listdir('/content/gdrive/MyDrive/CRAFT-txt/dev') if f.endswith('.txt')]:

  text = []
  data = []

  with open(filename) as f_in:
    
    paragraphs = [line for line in f_in.read().split('\n') if line]
  
    for paragraph in paragraphs:
      sentences = tokenizer.tokenize(paragraph)
      text.extend(sentences)
                
  chs = list(chunks(text, 100))

  N = len(chs)

  for i in range(0, N):
    
    text = chs[i]
    data.append(tokenize(text))

    file1 = "./data/in/"  + file[0:-4] + "_" + str(i) + ".json"
    file2 = "./data/out/" + file[0:-4] + "_" + str(i) + ".jsonlines"

    with open(file1, 'w') as out:
      json.dump(data[i], out, sort_keys=True)
    
    subprocess.call(['python', 'predict.py', 'spanbert_base', file1, file2])

# %%
! gpu=0 python predict.py $CHOSEN_MODEL ./data/in_0.json ./data/out_0.json
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# W0514 14:30:05.058650 139705853998976 deprecation_wrapper.py:119] From /content/coref/coref_ops.py:11: The name tf.NotDifferentiable is deprecated. Please use tf.no_gradient instead.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/linear_assignment_.py:21: DeprecationWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# W0514 14:30:05.100141 139705853998976 deprecation_wrapper.py:119] From /content/coref/bert/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0514 14:30:05.994991 139705853998976 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Running experiment: spanbert_base
# data_dir = "/sdb/data/new_coref"
# model_type = "independent"
# max_top_antecedents = 50
# max_training_sentences = 3
# top_span_ratio = 0.4
# max_num_speakers = 20
# max_segment_len = 384
# bert_learning_rate = 2e-05
# task_learning_rate = 0.0001
# num_docs = 2802
# dropout_rate = 0.3
# ffnn_size = 3000
# ffnn_depth = 1
# num_epochs = 20
# feature_size = 20
# max_span_width = 30
# use_metadata = true
# use_features = true
# use_segment_distance = true
# model_heads = true
# coref_depth = 2
# coarse_to_fine = true
# fine_grained = true
# use_prior = true
# train_path = "./data/train.english.384.jsonlines"
# eval_path = "./data/dev.english.384.jsonlines"
# conll_eval_path = "./data/dev.english.v4_gold_conll"
# single_example = true
# genres = [
#   "bc"
#   "bn"
#   "mz"
#   "nw"
#   "pt"
#   "tc"
#   "wb"
# ]
# eval_frequency = 1000
# report_frequency = 100
# log_root = "./data"
# adam_eps = 1e-06
# task_optimizer = "adam"
# bert_config_file = "./data/spanbert_base/bert_config.json"
# vocab_file = "./data/spanbert_base/vocab.txt"
# tf_checkpoint = "./data/spanbert_base/model.max.ckpt"
# init_checkpoint = "./data/spanbert_base/model.max.ckpt"
# log_dir = "./data/spanbert_base"
# W0514 14:30:06.056577 139705853998976 deprecation_wrapper.py:119] From /content/coref/bert/modeling.py:92: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0514 14:30:06.130739 139705853998976 deprecation_wrapper.py:119] From /content/coref/independent.py:48: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0514 14:30:06.136145 139705853998976 deprecation_wrapper.py:119] From /content/coref/independent.py:50: The name tf.PaddingFIFOQueue is deprecated. Please use tf.queue.PaddingFIFOQueue instead.
#
# W0514 14:30:06.139153 139705853998976 deprecation.py:323] From /content/coref/bert/modeling.py:158: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0514 14:30:06.150894 139705853998976 deprecation_wrapper.py:119] From /content/coref/bert/modeling.py:175: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0514 14:30:06.151029 139705853998976 deprecation_wrapper.py:119] From /content/coref/bert/modeling.py:175: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W0514 14:30:06.212574 139705853998976 deprecation.py:506] From /content/coref/bert/modeling.py:362: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0514 14:30:06.252979 139705853998976 deprecation.py:323] From /content/coref/bert/modeling.py:676: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0514 14:30:08.742758 139705853998976 deprecation.py:323] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0514 14:30:08.820300 139705853998976 deprecation.py:323] From /content/coref/independent.py:221: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0514 14:30:08.865341 139705853998976 deprecation_wrapper.py:119] From /content/coref/util.py:117: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
#
# W0514 14:30:09.371789 139705853998976 deprecation_wrapper.py:119] From /content/coref/independent.py:60: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# **** Trainable Variables ****
#   name = bert/embeddings/word_embeddings:0, shape = (28996, 768), *INIT_FROM_CKPT*
#   name = bert/embeddings/token_type_embeddings:0, shape = (2, 768), *INIT_FROM_CKPT*
#   name = bert/embeddings/position_embeddings:0, shape = (512, 768), *INIT_FROM_CKPT*
#   name = bert/embeddings/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/embeddings/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_0/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_1/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_2/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_3/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_4/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_5/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_6/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_7/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_8/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_9/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_10/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/self/query/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/self/query/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/self/key/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/self/key/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/self/value/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/self/value/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/output/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/attention/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/intermediate/dense/kernel:0, shape = (768, 3072), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/intermediate/dense/bias:0, shape = (3072,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/output/dense/kernel:0, shape = (3072, 768), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/output/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/output/LayerNorm/beta:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/encoder/layer_11/output/LayerNorm/gamma:0, shape = (768,), *INIT_FROM_CKPT*
#   name = bert/pooler/dense/kernel:0, shape = (768, 768), *INIT_FROM_CKPT*
#   name = bert/pooler/dense/bias:0, shape = (768,), *INIT_FROM_CKPT*
#   name = span_width_embeddings:0, shape = (30, 20), *INIT_FROM_CKPT*
#   name = mention_word_attn/output_weights:0, shape = (768, 1), *INIT_FROM_CKPT*
#   name = mention_word_attn/output_bias:0, shape = (1,), *INIT_FROM_CKPT*
#   name = mention_scores/hidden_weights_0:0, shape = (2324, 3000), *INIT_FROM_CKPT*
#   name = mention_scores/hidden_bias_0:0, shape = (3000,), *INIT_FROM_CKPT*
#   name = mention_scores/output_weights:0, shape = (3000, 1), *INIT_FROM_CKPT*
#   name = mention_scores/output_bias:0, shape = (1,), *INIT_FROM_CKPT*
#   name = span_width_prior_embeddings:0, shape = (30, 20), *INIT_FROM_CKPT*
#   name = width_scores/hidden_weights_0:0, shape = (20, 3000), *INIT_FROM_CKPT*
#   name = width_scores/hidden_bias_0:0, shape = (3000,), *INIT_FROM_CKPT*
#   name = width_scores/output_weights:0, shape = (3000, 1), *INIT_FROM_CKPT*
#   name = width_scores/output_bias:0, shape = (1,), *INIT_FROM_CKPT*
#   name = genre_embeddings:0, shape = (7, 20), *INIT_FROM_CKPT*
#   name = src_projection/output_weights:0, shape = (2324, 2324), *INIT_FROM_CKPT*
#   name = src_projection/output_bias:0, shape = (2324,), *INIT_FROM_CKPT*
#   name = antecedent_distance_emb:0, shape = (10, 20), *INIT_FROM_CKPT*
#   name = output_weights:0, shape = (20, 1), *INIT_FROM_CKPT*
#   name = output_bias:0, shape = (1,), *INIT_FROM_CKPT*
#   name = coref_layer/same_speaker_emb:0, shape = (2, 20), *INIT_FROM_CKPT*
#   name = coref_layer/antecedent_distance_emb:0, shape = (10, 20), *INIT_FROM_CKPT*
#   name = coref_layer/segment_distance/segment_distance_embeddings:0, shape = (3, 20), *INIT_FROM_CKPT*
#   name = coref_layer/slow_antecedent_scores/hidden_weights_0:0, shape = (7052, 3000), *INIT_FROM_CKPT*
#   name = coref_layer/slow_antecedent_scores/hidden_bias_0:0, shape = (3000,), *INIT_FROM_CKPT*
#   name = coref_layer/slow_antecedent_scores/output_weights:0, shape = (3000, 1), *INIT_FROM_CKPT*
#   name = coref_layer/slow_antecedent_scores/output_bias:0, shape = (1,), *INIT_FROM_CKPT*
#   name = coref_layer/f/output_weights:0, shape = (4648, 2324), *INIT_FROM_CKPT*
#   name = coref_layer/f/output_bias:0, shape = (2324,), *INIT_FROM_CKPT*
# W0514 14:30:10.151337 139705853998976 deprecation_wrapper.py:119] From /content/coref/independent.py:74: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# W0514 14:30:10.156309 139705853998976 deprecation_wrapper.py:119] From /content/coref/optimization.py:13: The name tf.train.polynomial_decay is deprecated. Please use tf.compat.v1.train.polynomial_decay instead.
#
# W0514 14:30:10.160013 139705853998976 deprecation.py:323] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/learning_rate_schedule.py:409: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0514 14:30:10.177911 139705853998976 deprecation_wrapper.py:119] From /content/coref/optimization.py:64: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# bert:task 199 27
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 2021-05-14 14:30:19.227100: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2021-05-14 14:30:19.264466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:19.265098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-14 14:30:19.265169: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2021-05-14 14:30:19.266619: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2021-05-14 14:30:19.268017: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2021-05-14 14:30:19.268382: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2021-05-14 14:30:19.270000: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2021-05-14 14:30:19.271407: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2021-05-14 14:30:19.275281: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2021-05-14 14:30:19.275541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:19.276155: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:19.276686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2021-05-14 14:30:19.277087: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-05-14 14:30:19.281846: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-05-14 14:30:19.282040: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56244eb6b640 executing computations on platform Host. Devices:
# 2021-05-14 14:30:19.282066: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2021-05-14 14:30:19.496864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:19.497961: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5624552d8a80 executing computations on platform CUDA. Devices:
# 2021-05-14 14:30:19.497998: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-05-14 14:30:19.498232: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:19.499008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-14 14:30:19.499094: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2021-05-14 14:30:19.499142: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2021-05-14 14:30:19.499166: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2021-05-14 14:30:19.499185: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2021-05-14 14:30:19.499203: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2021-05-14 14:30:19.499222: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2021-05-14 14:30:19.499242: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2021-05-14 14:30:19.499368: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:19.500192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:19.500834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2021-05-14 14:30:19.500907: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2021-05-14 14:30:22.788511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-14 14:30:22.788566: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2021-05-14 14:30:22.788579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2021-05-14 14:30:22.788805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:22.789491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-14 14:30:22.790010: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:40] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-05-14 14:30:22.790055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13533 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Restoring from ./data/spanbert_base/model.max.ckpt
# W0514 14:30:30.464008 139705853998976 deprecation.py:323] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-05-14 14:30:33.112483: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# Decoded 1 examples.

# %% [markdown]
# ### Using Evaulate
# currently not working

# %%
! gpu=0 python evaluate.py $CHOSEN_MODEL

# %% [markdown]
# ## Output

# %%
output = json.load(open("./data/dev_2.jsonlines"))

comb_text = [word for sentence in output['sentences'] for word in sentence]

def convert_mention(mention):
    start = output['subtoken_map'][mention[0]]
    end = output['subtoken_map'][mention[1]] + 1
    nmention = (start, end)
    mtext = ''.join(' '.join(comb_text[mention[0]:mention[1]+1]).split(" ##"))
    return (nmention, mtext)

seen = set()
print('Clusters:')
for cluster in output['predicted_clusters']:
    mapped = []
    for mention in cluster:
        seen.add(tuple(mention))
        mapped.append(convert_mention(mention))
    print(mapped, end=",\n")

print('\nMentions:')
for mention in output['top_spans']:
    if tuple(mention) in seen:
        continue
    print(convert_mention(mention), end=",\n")
# Out:
# Clusters:
# [((0, 1), 'We'), ((24, 25), 'we'), ((90, 91), 'we'), ((251, 252), 'we'), ((397, 398), 'we'), ((622, 623), 'we'), ((698, 699), 'we'), ((723, 724), 'We'), ((930, 931), 'we'), ((993, 994), 'we'), ((1130, 1131), 'us'), ((1158, 1159), 'we'), ((1205, 1206), 'our'), ((1270, 1271), 'We'), ((1685, 1686), 'we'), ((1824, 1825), 'our'), ((1833, 1834), 'We'), ((1847, 1848), 'we'), ((1859, 1860), 'Our'), ((1920, 1921), 'we'), ((1947, 1948), 'we')],
# [((54, 57), 'The mean CV'), ((67, 71), 'this relatively low CV')],
# [((97, 114), 'the DBA / 1 and FVB / N strains at all four phases of CIA , including NC , PI , OA and CA'), ((126, 129), 'the two strains'), ((135, 137), 'both strains'), ((164, 167), 'these two strains'), ((207, 210), 'the two strains'), ((600, 604), 'these two gene clusters'), ((644, 646), 'both lists'), ((818, 821), 'the two strains'), ((1282, 1288), 'both genetically susceptible and resistant strains'), ((1295, 1297), 'both strains'), ((1446, 1449), 'the two strains'), ((1510, 1512), 'both strains'), ((1816, 1818), 'two strains'), ((1916, 1919), 'the two strains')],
# [((107, 108), 'CIA'), ((143, 145), 'the disease'), ((154, 155), 'CIA'), ((230, 231), 'CIA'), ((250, 251), 'CIA'), ((262, 263), 'CIA'), ((307, 309), 'the disease'), ((320, 322), 'the disease'), ((343, 344), 'CIA'), ((381, 382), 'CIA'), ((396, 397), 'CIA'), ((425, 426), 'CIA'), ((439, 440), 'CIA'), ((453, 455), 'the disease'), ((487, 488), 'CIA'), ((611, 612), 'CIA'), ((619, 620), 'CIA'), ((783, 784), 'CIA'), ((809, 810), 'CIA'), ((834, 835), 'CIA'), ((861, 862), 'CIA'), ((991, 992), 'CIA'), ((1178, 1179), 'CIA'), ((1219, 1220), 'CIA'), ((1229, 1230), 'CIA'), ((1246, 1247), 'CIA'), ((1269, 1270), 'CIA'), ((1293, 1294), 'CIA'), ((1390, 1391), 'CIA'), ((1439, 1440), 'CIA'), ((1475, 1476), 'CIA'), ((1508, 1509), 'CIA'), ((1534, 1535), 'CIA'), ((1620, 1621), 'CIA'), ((1857, 1858), 'CIA'), ((1933, 1934), 'CIA'), ((1965, 1966), 'CIA')],
# [((98, 99), 'DBA / 1'), ((151, 152), 'DBA / 1'), ((853, 855), 'the DBA / 1'), ((873, 876), 'the DBA / 1 strain'), ((1087, 1088), 'DBA / 1'), ((1381, 1382), 'DBA / 1'), ((1422, 1425), 'the DBA / 1 strain'), ((1465, 1468), 'the DBA / 1 strain'), ((1490, 1493), 'the DBA / 1 strain')],
# [((103, 114), 'all four phases of CIA , including NC , PI , OA and CA'), ((183, 186), 'the four phases'), ((211, 213), 'all phases')],
# [((200, 202), 'Twenty - one genes'), ((214, 217), 'these 21 genes')],
# [((110, 111), 'PI'), ((232, 233), 'PI'), ((270, 271), 'PI'), ((357, 358), 'PI'), ((360, 361), 'PI'), ((882, 883), 'PI'), ((1305, 1306), 'PI'), ((1335, 1336), 'PI'), ((1392, 1393), 'PI')],
# [((113, 114), 'CA'), ((235, 236), 'CA'), ((273, 274), 'CA'), ((362, 363), 'CA'), ((366, 367), 'CA'), ((1307, 1308), 'CA'), ((1337, 1338), 'CA'), ((1402, 1403), 'CA')],
# [((109, 110), 'NC'), ((278, 279), 'NC'), ((823, 824), 'NC'), ((881, 882), 'NC'), ((1391, 1392), 'NC')],
# [((285, 287), '102 genes'), ((293, 294), 'them')],
# [((332, 335), 'Only one gene'), ((345, 347), 'this gene')],
# [((111, 112), 'OA'), ((359, 360), 'OA'), ((364, 365), 'OA'), ((1394, 1395), 'OA')],
# [((372, 377), '310 disease - specific differentially expressed genes'), ((403, 406), 'these 310 genes'), ((639, 641), '117 genes'), ((654, 661), 'the 117 genes retrieved from Ensembl [ 30 ]')],
# [((429, 440), '16 genes , representing genes that were upregulated after induction of CIA'), ((443, 445), 'these genes'), ((461, 462), 'they')],
# [((303, 309), 'the onset phase of the disease'), ((449, 455), 'the onset phase of the disease')],
# [((316, 322), 'the chronic phase of the disease'), ((483, 488), 'the chronic phase of CIA'), ((544, 547), 'the chronic phase'), ((805, 810), 'the chronic phase of CIA'), ((890, 893), 'the chronic phase')],
# [((471, 488), '12 genes whose expression was gradually upregulated and reached a peak at the chronic phase of CIA'), ((488, 490), 'These genes')],
# [((507, 517), '78 genes that were only upregulated at the PI phase'), ((517, 519), 'These genes'), ((547, 549), 'These genes')],
# [((504, 506), 'Cluster III'), ((567, 569), 'Cluster V'), ((577, 579), 'Cluster VI')],
# [((514, 517), 'the PI phase'), ((574, 577), 'the PI phase'), ((584, 587), 'the OA phase'), ((779, 784), 'the OA phase of CIA'), ((790, 793), 'the PI phase'), ((1341, 1344), 'the OA phase')],
# [((607, 612), 'the small - effect QTL of CIA'), ((618, 622), 'the CIA small - effect QTL'), ((1224, 1227), 'the small - effect QTL')],
# [((664, 668), 'the 8 small - effect QTL'), ((668, 671), 'The eight loci'), ((707, 709), 'all loci'), ((720, 723), 'the eight QTL'), ((982, 986), 'the eight small - effect QTL'), ((1017, 1021), 'the eight small - effect QTL'), ((1030, 1032), 'these QTL'), ((1072, 1075), 'these eight QTL'), ((1082, 1086), 'the eight small - effect QTL'), ((1523, 1527), 'the eight small - effect QTL'), ((1731, 1745), 'the eight small - effect QTL identified using a very low threshold value ( P < 0 . 05 )')],
# [((775, 776), 'Oas1a'), ((785, 786), 'Oas1a'), ((813, 814), 'hspa1a')],
# [((771, 776), 'Two genes , hspa1a and Oas1a'), ((795, 798), 'these two genes')],
# [((339, 344), 'all three phases of CIA'), ((831, 835), 'all phases of CIA')],
# [((825, 827), 'Five genes'), ((843, 846), 'these five genes')],
# [((836, 837), 'H2 - Q10'), ((846, 847), 'H2 - Q10')],
# [((264, 267), 'the susceptible strain'), ((856, 859), 'the FVB / N strain'), ((1114, 1117), 'the resistant strain'), ((1354, 1356), 'the susceptible'), ((1431, 1434), 'the FVB / N strain'), ((1471, 1474), 'the FVB / N strain'), ((1495, 1498), 'the FVB / N strain')],
# [((100, 101), 'FVB / N'), ((857, 858), 'FVB / N'), ((1095, 1096), 'FVBN'), ((1384, 1385), 'FVB / N'), ((1432, 1433), 'FVB / N'), ((1496, 1497), 'FVB / N')],
# [((899, 906), 'the functional cluster of protein kinase cascade'), ((914, 917), 'This functional cluster')],
# [((837, 838), 'Mapk14'), ((921, 922), 'Mapk14')],
# [((769, 771), 'this study'), ((928, 930), 'this study'), ((1039, 1042), 'the present study')],
# [((691, 692), 'F2'), ((942, 943), 'F2'), ((1134, 1135), 'F2')],
# [((756, 760), 'loci 4 and 7'), ((1118, 1122), 'loci 2 and 7'), ((1545, 1549), 'QTL 4 and 7'), ((1558, 1561), 'these two QTL')],
# [((1147, 1157), 'Cia27 , a QTL controlling IgG2a antibody levels to collagen II'), ((1161, 1163), 'this QTL')],
# [((1164, 1169), 'a 4 . 1 Mb genomic region'), ((1175, 1177), 'this region')],
# [((1193, 1195), 'chromosome 16'), ((1211, 1213), 'chromosome 17')],
# [((1172, 1177), 'a gene within this region'), ((1221, 1227), 'the gene within the small - effect QTL')],
# [((168, 173), 'the onset and chronic phases'), ((1304, 1309), 'the PI and CA phases'), ((1334, 1339), 'the PI and CA phases')],
# [((1366, 1374), 'one cluster of genes ( cluster IV , Figure 2 )'), ((1374, 1376), 'These genes'), ((1409, 1411), 'these genes')],
# [((1512, 1514), 'Twenty - one genes'), ((1529, 1530), 'their'), ((1536, 1537), 'their')],
# [((1616, 1618), 'p38 MAPK'), ((1625, 1627), 'p38 MAPK')],
# [((1078, 1079), 'RA'), ((1634, 1635), 'RA'), ((1946, 1947), 'RA'), ((1958, 1959), 'RA'), ((2015, 2016), 'RA')],
# [((1636, 1643), 'Stat5a , a candidate gene for loci 6 ,'), ((1653, 1654), 'Stat5a'), ((1667, 1668), 'Stat5a')],
# [((1692, 1694), 'small - effect QTL'), ((1701, 1702), 'them')],
# [((1582, 1583), 'arthritis'), ((1768, 1769), 'arthritis'), ((1889, 1890), 'arthritis')],
# [((1835, 1844), 'a strategy to search candidate genes for small - effect QTL'), ((1845, 1847), 'this strategy')],
# [((1904, 1906), 'Candidate genes'), ((1911, 1912), 'their')],
#
# Mentions:
# ((0, 2), 'We detected'),
# ((0, 16), 'We detected the gene expression profiles using three mice per group , which is a small number'),
# ((0, 16), 'We detected the gene expression profiles using three mice per group , which is a small number .'),
# ((1, 2), 'detected'),
# ((2, 6), 'the gene expression profiles'),
# ((2, 16), 'the gene expression profiles using three mice per group , which is a small number'),
# ((6, 7), 'using'),
# ((7, 9), 'three mice'),
# ((7, 11), 'three mice per group'),
# ((7, 16), 'three mice per group , which is a small number'),
# ((9, 11), 'per group'),
# ((10, 11), 'group'),
# ((12, 13), 'is'),
# ((13, 16), 'a small number'),
# ((16, 17), 'Being'),
# ((16, 26), 'Being aware of the importance of data reproducibility , we determined'),
# ((17, 26), 'aware of the importance of data reproducibility , we determined'),
# ((19, 24), 'the importance of data reproducibility'),
# ((19, 26), 'the importance of data reproducibility , we determined'),
# ((22, 24), 'data reproducibility'),
# ((23, 26), ', we determined'),
# ((24, 26), 'we determined'),
# ((25, 26), 'determined'),
# ((26, 31), 'the coefficient of variation ( CV )'),
# ((26, 35), 'the coefficient of variation ( CV ) to measure data variability'),
# ((27, 31), 'coefficient of variation ( CV )'),
# ((32, 33), 'measure'),
# ((33, 35), 'data variability'),
# ((35, 43), 'The CV for each gene on the chip'),
# ((35, 52), 'The CV for each gene on the chip and the mean CV for the entire probe set'),
# ((35, 54), 'The CV for each gene on the chip and the mean CV for the entire probe set were calculated'),
# ((38, 43), 'each gene on the chip'),
# ((41, 43), 'the chip'),
# ((44, 47), 'the mean CV'),
# ((44, 52), 'the mean CV for the entire probe set'),
# ((48, 52), 'the entire probe set'),
# ((52, 53), 'were'),
# ((52, 54), 'were calculated'),
# ((53, 54), 'calculated'),
# ((54, 62), 'The mean CV ranged between 18 . 4 % and 25 . 8 %'),
# ((54, 66), 'The mean CV ranged between 18 . 4 % and 25 . 8 % for all experimental groups'),
# ((54, 66), 'The mean CV ranged between 18 . 4 % and 25 . 8 % for all experimental groups ,'),
# ((54, 71), 'The mean CV ranged between 18 . 4 % and 25 . 8 % for all experimental groups , and this relatively low CV'),
# ((57, 58), 'ranged'),
# ((57, 62), 'ranged between 18 . 4 % and 25 . 8 %'),
# ((63, 66), 'all experimental groups'),
# ((73, 75), 'these data'),
# ((73, 83), 'these data could be used for further analysis ( Table 1 ) .'),
# ((79, 81), 'further analysis'),
# ((81, 83), 'Table 1'),
# ((81, 83), 'Table 1 )'),
# ((81, 83), 'Table 1 ) .'),
# ((82, 83), '.'),
# ((84, 85), 'search'),
# ((86, 90), 'strain - specific differentially expressed genes'),
# ((91, 92), 'performed'),
# ((94, 96), 'gene expression'),
# ((98, 99), 'DB'),
# ((98, 99), 'DBA'),
# ((98, 114), 'DBA / 1 and FVB / N strains at all four phases of CIA , including NC , PI , OA and CA'),
# ((98, 99), '/ 1'),
# ((98, 99), '1'),
# ((100, 102), 'FVB / N strains'),
# ((100, 114), 'FVB / N strains at all four phases of CIA , including NC , PI , OA and CA'),
# ((100, 101), 'N'),
# ((103, 108), 'all four phases of CIA'),
# ((109, 112), 'NC , PI , OA'),
# ((109, 114), 'NC , PI , OA and CA'),
# ((110, 112), 'PI , OA'),
# ((110, 111), '##I'),
# ((111, 112), 'O'),
# ((115, 120), 'the naive mice without immunisation'),
# ((115, 120), 'the naive mice without immunisation ,'),
# ((115, 129), 'the naive mice without immunisation , 361 genes were differentially expressed between the two strains'),
# ((119, 120), 'immunisation'),
# ((120, 122), '361 genes'),
# ((120, 129), '361 genes were differentially expressed between the two strains'),
# ((123, 125), 'differentially expressed'),
# ((129, 150), 'On day 10 after immunisation , when both strains did not show any sign of the disease , 141 genes were differentially expressed'),
# ((130, 134), 'day 10 after immunisation'),
# ((130, 150), 'day 10 after immunisation , when both strains did not show any sign of the disease , 141 genes were differentially expressed'),
# ((133, 134), 'immunisation'),
# ((135, 145), 'both strains did not show any sign of the disease'),
# ((135, 145), 'both strains did not show any sign of the disease ,'),
# ((135, 150), 'both strains did not show any sign of the disease , 141 genes were differentially expressed'),
# ((137, 138), 'did'),
# ((137, 140), 'did not show'),
# ((138, 140), 'not show'),
# ((139, 140), 'show'),
# ((145, 147), '141 genes'),
# ((145, 150), '141 genes were differentially expressed'),
# ((148, 150), 'differentially expressed'),
# ((149, 150), 'expressed'),
# ((151, 153), 'DBA / 1 mice'),
# ((151, 154), 'DBA / 1 mice developed'),
# ((151, 155), 'DBA / 1 mice developed CIA'),
# ((151, 155), 'DBA / 1 mice developed CIA ,'),
# ((151, 174), 'DBA / 1 mice developed CIA , 184 and 85 differentially expressed genes were identified between these two strains at the onset and chronic phases , respectively'),
# ((153, 154), 'developed'),
# ((155, 161), '184 and 85 differentially expressed genes'),
# ((155, 163), '184 and 85 differentially expressed genes were identified'),
# ((155, 174), '184 and 85 differentially expressed genes were identified between these two strains at the onset and chronic phases , respectively'),
# ((162, 163), 'identified'),
# ((164, 174), 'these two strains at the onset and chronic phases , respectively'),
# ((168, 174), 'the onset and chronic phases , respectively'),
# ((171, 172), 'chronic'),
# ((173, 174), 'respectively'),
# ((175, 186), 'the lists of the differentially expressed genes at the four phases'),
# ((175, 197), 'the lists of the differentially expressed genes at the four phases were merged and overlapping genes were excluded , 509 genes were identified'),
# ((178, 186), 'the differentially expressed genes at the four phases'),
# ((187, 188), 'merged'),
# ((189, 191), 'overlapping genes'),
# ((192, 193), 'excluded'),
# ((193, 195), '509 genes'),
# ((193, 197), '509 genes were identified'),
# ((196, 197), 'identified'),
# ((197, 200), 'Additional file 1'),
# ((197, 200), 'Additional file 1 )'),
# ((200, 210), 'Twenty - one genes consistently showed differential expression between the two strains'),
# ((200, 213), 'Twenty - one genes consistently showed differential expression between the two strains at all phases'),
# ((202, 204), 'consistently showed'),
# ((203, 204), 'showed'),
# ((217, 221), 'only 3 additional genes'),
# ((217, 232), 'only 3 additional genes were strain - specific differentially expressed during the 3 phases after CIA induction'),
# ((217, 238), 'only 3 additional genes were strain - specific differentially expressed during the 3 phases after CIA induction ( PI , OA and CA ; Figure 1 )'),
# ((221, 222), 'were'),
# ((222, 225), 'strain - specific differentially expressed'),
# ((226, 232), 'the 3 phases after CIA induction'),
# ((230, 232), 'CIA induction'),
# ((232, 236), 'PI , OA and CA'),
# ((232, 238), 'PI , OA and CA ; Figure 1 )'),
# ((232, 233), '##I'),
# ((233, 234), 'OA'),
# ((236, 238), 'Figure 1'),
# ((236, 238), 'Figure 1 )'),
# ((237, 238), '1'),
# ((238, 242), 'Disease - specific differentially expressed genes'),
# ((242, 244), 'To identify'),
# ((243, 244), 'identify'),
# ((244, 251), 'the disease - specific differentially expressed genes in CIA'),
# ((244, 267), 'the disease - specific differentially expressed genes in CIA , we detected the genes that were differentially expressed in LNs during CIA in the susceptible strain'),
# ((251, 253), 'we detected'),
# ((251, 267), 'we detected the genes that were differentially expressed in LNs during CIA in the susceptible strain'),
# ((252, 253), 'detected'),
# ((253, 263), 'the genes that were differentially expressed in LNs during CIA'),
# ((253, 267), 'the genes that were differentially expressed in LNs during CIA in the susceptible strain'),
# ((257, 259), 'differentially expressed'),
# ((258, 259), 'expressed'),
# ((260, 261), 'LN'),
# ((260, 261), 'LNs'),
# ((260, 263), 'LNs during CIA'),
# ((265, 266), 'susceptible'),
# ((265, 267), 'susceptible strain'),
# ((266, 267), 'strain'),
# ((267, 270), 'Three experimental conditions'),
# ((267, 274), 'Three experimental conditions , PI , OA and CA'),
# ((267, 274), 'Three experimental conditions , PI , OA and CA ,'),
# ((267, 280), 'Three experimental conditions , PI , OA and CA , were compared with the NC group . [SEP]'),
# ((270, 274), 'PI , OA and CA'),
# ((271, 272), 'OA'),
# ((274, 275), 'were'),
# ((275, 276), 'compared'),
# ((275, 280), 'compared with the NC group . [SEP]'),
# ((277, 280), 'the NC group'),
# ((277, 280), 'the NC group .'),
# ((277, 280), 'the NC group . [SEP]'),
# ((278, 280), 'NC group'),
# ((279, 280), 'group'),
# ((280, 285), 'On day 10 after immunisation'),
# ((280, 300), 'On day 10 after immunisation , 102 genes were differentially expressed – most of them were upregulated ( 78 out of 102 )'),
# ((281, 285), 'day 10 after immunisation'),
# ((284, 285), 'immunisation'),
# ((285, 300), '102 genes were differentially expressed – most of them were upregulated ( 78 out of 102 )'),
# ((287, 288), 'were'),
# ((288, 290), 'differentially expressed'),
# ((296, 300), '78 out of 102'),
# ((299, 300), '102'),
# ((303, 315), 'the onset phase of the disease , only 26 genes were differentially expressed'),
# ((309, 312), 'only 26 genes'),
# ((309, 315), 'only 26 genes were differentially expressed'),
# ((313, 315), 'differentially expressed'),
# ((316, 332), 'the chronic phase of the disease , 184 differentially expressed genes were identified , with 156 downregulated genes'),
# ((322, 326), '184 differentially expressed genes'),
# ((322, 328), '184 differentially expressed genes were identified'),
# ((322, 332), '184 differentially expressed genes were identified , with 156 downregulated genes'),
# ((327, 328), 'identified'),
# ((329, 330), '156'),
# ((329, 332), '156 downregulated genes'),
# ((332, 344), 'Only one gene was differentially expressed at all three phases of CIA'),
# ((336, 338), 'differentially expressed'),
# ((345, 354), 'this gene , five , one and six differentially expressed genes'),
# ((347, 354), 'five , one and six differentially expressed genes'),
# ((357, 360), 'PI with OA'),
# ((357, 367), 'PI with OA , PI with CA and OA with CA'),
# ((357, 367), 'PI with OA , PI with CA and OA with CA ,'),
# ((357, 368), 'PI with OA , PI with CA and OA with CA , respectively'),
# ((357, 370), 'PI with OA , PI with CA and OA with CA , respectively ( Figure 2a )'),
# ((357, 370), 'PI with OA , PI with CA and OA with CA , respectively ( Figure 2a ) .'),
# ((360, 367), 'PI with CA and OA with CA'),
# ((362, 367), 'CA and OA with CA'),
# ((364, 367), 'OA with CA'),
# ((368, 370), 'Figure 2a'),
# ((368, 370), 'Figure 2a )'),
# ((372, 382), '310 disease - specific differentially expressed genes were differentially regulated during CIA'),
# ((372, 385), '310 disease - specific differentially expressed genes were differentially regulated during CIA in DBA / 1 mice'),
# ((377, 378), 'were'),
# ((378, 380), 'differentially regulated'),
# ((383, 384), 'DBA / 1'),
# ((383, 385), 'DBA / 1 mice'),
# ((383, 384), '/ 1'),
# ((383, 384), '1'),
# ((385, 388), 'Additional file 2'),
# ((385, 388), 'Additional file 2 )'),
# ((385, 388), 'Additional file 2 ) .'),
# ((391, 397), 'the gene expression pattern during CIA'),
# ((391, 406), 'the gene expression pattern during CIA , we performed hierarchical cluster analysis for these 310 genes'),
# ((397, 399), 'we performed'),
# ((398, 399), 'performed'),
# ((399, 406), 'hierarchical cluster analysis for these 310 genes'),
# ((406, 409), 'Six gene clusters'),
# ((406, 426), 'Six gene clusters were identified ( clusters I to VI , Figure 2b ) , each with a distinct gene expression pattern during CIA'),
# ((409, 411), 'were identified'),
# ((410, 411), 'identified'),
# ((411, 415), 'clusters I to VI'),
# ((411, 417), 'clusters I to VI , Figure 2b'),
# ((411, 417), 'clusters I to VI , Figure 2b )'),
# ((411, 426), 'clusters I to VI , Figure 2b ) , each with a distinct gene expression pattern during CIA'),
# ((412, 413), 'I'),
# ((414, 415), 'VI'),
# ((415, 417), 'Figure 2b'),
# ((417, 426), 'each with a distinct gene expression pattern during CIA'),
# ((419, 426), 'a distinct gene expression pattern during CIA'),
# ((426, 428), 'Cluster I'),
# ((426, 440), 'Cluster I contains 16 genes , representing genes that were upregulated after induction of CIA'),
# ((428, 429), 'contains'),
# ((432, 440), 'genes that were upregulated after induction of CIA'),
# ((437, 440), 'induction of CIA'),
# ((440, 445), 'The expression of these genes'),
# ((440, 455), 'The expression of these genes reached a peak at the onset phase of the disease'),
# ((440, 468), 'The expression of these genes reached a peak at the onset phase of the disease and functional clustering results revealed that they are related to the immune response'),
# ((445, 446), 'reached'),
# ((465, 468), 'the immune response'),
# ((468, 470), 'Cluster II'),
# ((468, 488), 'Cluster II contains 12 genes whose expression was gradually upregulated and reached a peak at the chronic phase of CIA'),
# ((470, 471), 'contains'),
# ((488, 504), 'These genes are mainly related to the immune response , organelle membrane and extracellular region and space'),
# ((494, 497), 'the immune response'),
# ((494, 504), 'the immune response , organelle membrane and extracellular region and space'),
# ((497, 499), 'organelle membrane'),
# ((497, 504), 'organelle membrane and extracellular region and space'),
# ((500, 504), 'extracellular region and space'),
# ((504, 517), 'Cluster III contains 78 genes that were only upregulated at the PI phase'),
# ((506, 507), 'contains'),
# ((515, 516), 'PI'),
# ((517, 525), 'These genes are related to the intercellular junction'),
# ((522, 525), 'the intercellular junction'),
# ((525, 534), 'More than half of the genes ( 156 of 310 )'),
# ((525, 535), 'More than half of the genes ( 156 of 310 ) belong'),
# ((525, 538), 'More than half of the genes ( 156 of 310 ) belong to cluster IV'),
# ((525, 540), 'More than half of the genes ( 156 of 310 ) belong to cluster IV and represent'),
# ((525, 547), 'More than half of the genes ( 156 of 310 ) belong to cluster IV and represent genes specifically downregultaed at the chronic phase . [SEP]'),
# ((529, 531), 'the genes'),
# ((529, 534), 'the genes ( 156 of 310 )'),
# ((531, 534), '156 of 310'),
# ((531, 534), '156 of 310 )'),
# ((533, 534), '310'),
# ((534, 535), 'belong'),
# ((536, 538), 'cluster IV'),
# ((539, 540), 'represent'),
# ((540, 547), 'genes specifically downregultaed at the chronic phase . [SEP]'),
# ((544, 547), 'the chronic phase .'),
# ((544, 547), 'the chronic phase . [SEP]'),
# ((547, 567), 'These genes are functionally related to lymphocyte proliferation , T cell activation , protein binding as well as the notch signal pathway'),
# ((553, 555), 'lymphocyte proliferation'),
# ((553, 560), 'lymphocyte proliferation , T cell activation , protein binding'),
# ((553, 567), 'lymphocyte proliferation , T cell activation , protein binding as well as the notch signal pathway'),
# ((555, 557), 'T cell'),
# ((555, 558), 'T cell activation'),
# ((558, 560), 'protein binding'),
# ((563, 567), 'the notch signal pathway'),
# ((567, 577), 'Cluster V contains eight genes downregulated at the PI phase'),
# ((569, 570), 'contains'),
# ((570, 573), 'eight genes downregulated'),
# ((570, 577), 'eight genes downregulated at the PI phase'),
# ((575, 576), 'PI'),
# ((577, 587), 'Cluster VI contains 18 genes downregulated at the OA phase'),
# ((579, 580), 'contains'),
# ((580, 587), '18 genes downregulated at the OA phase'),
# ((585, 586), 'OA'),
# ((587, 591), 'The GO term classification'),
# ((587, 604), 'The GO term classification showed no functional cluster that was significantly enriched in these two gene clusters'),
# ((591, 592), 'showed'),
# ((604, 612), 'Candidate genes for the small - effect QTL of CIA'),
# ((612, 624), 'To identify candidate susceptibility genes for the CIA small - effect QTL , we compared'),
# ((613, 614), 'identify'),
# ((613, 624), 'identify candidate susceptibility genes for the CIA small - effect QTL , we compared'),
# ((614, 622), 'candidate susceptibility genes for the CIA small - effect QTL'),
# ((614, 622), 'candidate susceptibility genes for the CIA small - effect QTL ,'),
# ((614, 624), 'candidate susceptibility genes for the CIA small - effect QTL , we compared'),
# ((622, 624), 'we compared'),
# ((623, 624), 'compared'),
# ((624, 631), 'the list of strain - specific differentially expressed genes'),
# ((624, 639), 'the list of strain - specific differentially expressed genes with the list of disease - specific differentially expressed genes'),
# ((624, 641), 'the list of strain - specific differentially expressed genes with the list of disease - specific differentially expressed genes ; 117 genes'),
# ((624, 646), 'the list of strain - specific differentially expressed genes with the list of disease - specific differentially expressed genes ; 117 genes were shared by both lists'),
# ((627, 630), 'strain - specific differentially expressed'),
# ((632, 639), 'the list of disease - specific differentially expressed genes'),
# ((635, 638), 'disease - specific differentially expressed'),
# ((635, 639), 'disease - specific differentially expressed genes'),
# ((646, 649), 'Additional file 3 )'),
# ((649, 651), 'Figure 3'),
# ((649, 668), 'Figure 3 visualises positions of the 117 genes retrieved from Ensembl [ 30 ] in relation to the 8 small - effect QTL'),
# ((651, 652), 'visualises'),
# ((654, 668), 'the 117 genes retrieved from Ensembl [ 30 ] in relation to the 8 small - effect QTL'),
# ((659, 661), 'Ensembl [ 30 ]'),
# ((668, 684), 'The eight loci were located on 7 chromosomes , 5 , 6 , 7 , 10 , 11 , 16 and 17'),
# ((672, 673), 'located'),
# ((672, 684), 'located on 7 chromosomes , 5 , 6 , 7 , 10 , 11 , 16 and 17'),
# ((674, 684), '7 chromosomes , 5 , 6 , 7 , 10 , 11 , 16 and 17'),
# ((676, 677), '5'),
# ((679, 680), '10'),
# ((680, 681), '11'),
# ((681, 682), '16'),
# ((683, 684), '17'),
# ((685, 693), 'the confidence intervals of QTL in F2 progeny'),
# ((685, 698), 'the confidence intervals of QTL in F2 progeny are around 20 cM [ 26 ]'),
# ((685, 702), 'the confidence intervals of QTL in F2 progeny are around 20 cM [ 26 ] , we used 40 Mb'),
# ((689, 690), 'QTL'),
# ((689, 693), 'QTL in F2 progeny'),
# ((691, 693), 'F2 pro'),
# ((691, 693), 'F2 progeny'),
# ((693, 694), 'are'),
# ((698, 700), 'we used'),
# ((698, 702), 'we used 40 Mb'),
# ((699, 700), 'used'),
# ((700, 702), '40 Mb'),
# ((703, 709), 'the confidence intervals for all loci'),
# ((709, 711), 'Twenty - one genes'),
# ((709, 723), 'Twenty - one genes were located in the confidence intervals of six of the eight QTL'),
# ((712, 713), 'located'),
# ((714, 723), 'the confidence intervals of six of the eight QTL'),
# ((718, 723), 'six of the eight QTL'),
# ((723, 725), 'We located'),
# ((723, 735), 'We located 5 , 4 , 2 , 1 , 3 and 6 potential candidate genes'),
# ((724, 725), 'located'),
# ((725, 726), '5'),
# ((725, 732), '5 , 4 , 2 , 1 , 3 and 6'),
# ((725, 735), '5 , 4 , 2 , 1 , 3 and 6 potential candidate genes'),
# ((731, 732), '6'),
# ((736, 748), 'the confidence intervals of loci 1 , 2 , 3 , 5 , 6 and 8'),
# ((736, 749), 'the confidence intervals of loci 1 , 2 , 3 , 5 , 6 and 8 , respectively'),
# ((736, 749), 'the confidence intervals of loci 1 , 2 , 3 , 5 , 6 and 8 , respectively ,'),
# ((740, 748), 'loci 1 , 2 , 3 , 5 , 6 and 8'),
# ((744, 745), '5'),
# ((745, 746), '6'),
# ((747, 748), '8'),
# ((748, 749), 'respectively'),
# ((754, 755), 'identified'),
# ((756, 760), 'loci 4 and 7 .'),
# ((760, 762), 'Table 3'),
# ((760, 771), 'Table 3 summarises the 21 candidate genes identified in this study'),
# ((760, 771), 'Table 3 summarises the 21 candidate genes identified in this study .'),
# ((762, 763), 'summarises'),
# ((763, 771), 'the 21 candidate genes identified in this study'),
# ((767, 768), 'identified'),
# ((771, 776), 'Two genes , hspa1a and Oas1a ,'),
# ((773, 774), 'hspa1a'),
# ((773, 776), 'hspa1a and Oas1a'),
# ((775, 776), ','),
# ((776, 777), 'were'),
# ((779, 793), 'the OA phase of CIA and Oas1a was also upregulated at the PI phase'),
# ((779, 793), 'the OA phase of CIA and Oas1a was also upregulated at the PI phase .'),
# ((779, 793), 'the OA phase of CIA and Oas1a was also upregulated at the PI phase . [SEP]'),
# ((780, 781), 'OA'),
# ((785, 793), 'Oas1a was also upregulated at the PI phase'),
# ((791, 792), 'PI'),
# ((795, 802), 'these two genes , all other 19 genes'),
# ((795, 810), 'these two genes , all other 19 genes were downregulated at the chronic phase of CIA'),
# ((798, 802), 'all other 19 genes'),
# ((810, 812), 'All genes'),
# ((810, 814), 'All genes , except hspa1a'),
# ((810, 814), 'All genes , except hspa1a ,'),
# ((810, 821), 'All genes , except hspa1a , showed expression differences between the two strains'),
# ((810, 825), 'All genes , except hspa1a , showed expression differences between the two strains at the NC phase'),
# ((810, 825), 'All genes , except hspa1a , showed expression differences between the two strains at the NC phase .'),
# ((814, 815), 'showed'),
# ((822, 825), 'the NC phase'),
# ((828, 830), 'differentially expressed'),
# ((829, 830), 'expressed'),
# ((836, 842), 'H2 - Q10 , Mapk14 , Pscd1 , Kpnb1 and Wdr1'),
# ((837, 842), 'Mapk14 , Pscd1 , Kpnb1 and Wdr1'),
# ((838, 839), 'Pscd'),
# ((838, 839), 'Pscd1'),
# ((838, 840), 'Pscd1 , Kpnb1'),
# ((838, 842), 'Pscd1 , Kpnb1 and Wdr1'),
# ((839, 840), 'Kpnb1'),
# ((841, 842), 'Wdr1'),
# ((846, 863), 'H2 - Q10 had a consistently higher expression in the DBA / 1 than the FVB / N strain in all CIA phases'),
# ((846, 863), 'H2 - Q10 had a consistently higher expression in the DBA / 1 than the FVB / N strain in all CIA phases ,'),
# ((847, 848), 'had'),
# ((848, 863), 'a consistently higher expression in the DBA / 1 than the FVB / N strain in all CIA phases'),
# ((853, 863), 'the DBA / 1 than the FVB / N strain in all CIA phases'),
# ((856, 863), 'the FVB / N strain in all CIA phases'),
# ((857, 858), 'F'),
# ((857, 858), 'FVB'),
# ((857, 859), 'FVB / N strain'),
# ((860, 863), 'all CIA phases'),
# ((864, 868), 'the other four genes'),
# ((868, 869), 'had'),
# ((873, 885), 'the DBA / 1 strain at the early stages , including NC , PI and OA'),
# ((873, 885), 'the DBA / 1 strain at the early stages , including NC , PI and OA ,'),
# ((873, 893), 'the DBA / 1 strain at the early stages , including NC , PI and OA , but a lower expression at the chronic phase'),
# ((877, 885), 'the early stages , including NC , PI and OA'),
# ((881, 885), 'NC , PI and OA'),
# ((882, 885), 'PI and OA'),
# ((882, 883), '##I'),
# ((884, 885), 'O'),
# ((884, 885), 'OA'),
# ((893, 894), 'GO'),
# ((893, 897), 'GO term classification analysis'),
# ((893, 914), 'GO term classification analysis revealed that the functional cluster of protein kinase cascade was significantly enriched in the 21 candidate genes'),
# ((897, 898), 'revealed'),
# ((899, 914), 'the functional cluster of protein kinase cascade was significantly enriched in the 21 candidate genes'),
# ((903, 906), 'protein kinase cascade'),
# ((906, 907), 'was'),
# ((910, 914), 'the 21 candidate genes'),
# ((914, 926), 'This functional cluster contained four genes , including Mapk14 , Mapk8ip3 , Stat5a and Gna12'),
# ((917, 918), 'contained'),
# ((918, 926), 'four genes , including Mapk14 , Mapk8ip3 , Stat5a and Gna12'),
# ((921, 926), 'Mapk14 , Mapk8ip3 , Stat5a and Gna12'),
# ((922, 923), 'Mapk8ip3'),
# ((922, 926), 'Mapk8ip3 , Stat5a and Gna12'),
# ((923, 924), 'Stat5'),
# ((923, 924), 'Stat5a'),
# ((923, 926), 'Stat5a and Gna12'),
# ((925, 926), 'Gna'),
# ((925, 926), 'Gna12'),
# ((926, 927), 'Discussion'),
# ((928, 944), 'this study , we attempted for the first time to identify small - effect QTL in an F2 progeny'),
# ((928, 944), 'this study , we attempted for the first time to identify small - effect QTL in an F2 progeny .'),
# ((929, 930), 'study'),
# ((930, 938), 'we attempted for the first time to identify'),
# ((930, 944), 'we attempted for the first time to identify small - effect QTL in an F2 progeny'),
# ((931, 932), 'attempted'),
# ((931, 936), 'attempted for the first time'),
# ((931, 938), 'attempted for the first time to identify'),
# ((933, 936), 'the first time'),
# ((937, 938), 'identify'),
# ((938, 944), 'small - effect QTL in an F2 progeny'),
# ((941, 944), 'an F2 progeny'),
# ((942, 944), 'F2 pro'),
# ((942, 943), '##2'),
# ((944, 946), 'Small - effect QTL'),
# ((947, 948), 'defined'),
# ((951, 958), 'the threshold value of P = 0 . 05'),
# ((951, 973), 'the threshold value of P = 0 . 05 but that did not reach the significant threshold value suggested by Lander and Botstein [ 26 ]'),
# ((955, 958), 'P = 0 . 05'),
# ((969, 972), 'Lander and Botstein'),
# ((969, 973), 'Lander and Botstein [ 26 ]'),
# ((971, 972), 'Botstein'),
# ((972, 973), '[ 26 ]'),
# ((980, 986), 'most of the eight small - effect QTL'),
# ((980, 988), 'most of the eight small - effect QTL likely contain'),
# ((980, 992), 'most of the eight small - effect QTL likely contain susceptibility genes for CIA'),
# ((980, 992), 'most of the eight small - effect QTL likely contain susceptibility genes for CIA .'),
# ((986, 987), 'likely'),
# ((986, 988), 'likely contain'),
# ((987, 988), 'contain'),
# ((988, 992), 'susceptibility genes for CIA'),
# ((992, 993), 'First'),
# ((992, 995), 'First , we performed'),
# ((993, 995), 'we performed'),
# ((994, 995), 'performed'),
# ((995, 998), 'the linkage analysis'),
# ((1002, 1006), 'all 290 F progeny'),
# ((1002, 1015), 'all 290 F progeny , 76 C5 + / + F2 progeny and 133 C5 + / - F2 progeny'),
# ((1004, 1005), 'F'),
# ((1006, 1010), '76 C5 + / + F2 progeny'),
# ((1006, 1015), '76 C5 + / + F2 progeny and 133 C5 + / - F2 progeny'),
# ((1008, 1009), 'F'),
# ((1008, 1009), 'F2'),
# ((1008, 1010), 'F2 pro'),
# ((1008, 1010), 'F2 progeny'),
# ((1011, 1014), '133 C5 + / - F2'),
# ((1011, 1015), '133 C5 + / - F2 pro'),
# ((1011, 1015), '133 C5 + / - F2 progeny'),
# ((1012, 1014), 'C5 + / - F2'),
# ((1012, 1014), '+ / - F2'),
# ((1012, 1014), '/ - F2'),
# ((1012, 1014), '- F2'),
# ((1013, 1014), 'F'),
# ((1013, 1014), 'F2'),
# ((1014, 1015), '.'),
# ((1015, 1021), 'Five of the eight small - effect QTL'),
# ((1015, 1023), 'Five of the eight small - effect QTL were identified'),
# ((1015, 1028), 'Five of the eight small - effect QTL were identified in at least two datasets'),
# ((1015, 1032), 'Five of the eight small - effect QTL were identified in at least two datasets , suggesting that these QTL'),
# ((1015, 1034), 'Five of the eight small - effect QTL were identified in at least two datasets , suggesting that these QTL are reproducible'),
# ((1015, 1034), 'Five of the eight small - effect QTL were identified in at least two datasets , suggesting that these QTL are reproducible .'),
# ((1021, 1022), 'were'),
# ((1021, 1023), 'were identified'),
# ((1022, 1023), 'identified'),
# ((1024, 1028), 'at least two datasets'),
# ((1033, 1034), 'reproducible'),
# ((1034, 1035), 'Second'),
# ((1035, 1042), 'many QTL identified in the present study'),
# ((1035, 1055), 'many QTL identified in the present study overlap with arthritis QTL previously identified , including loci 1 , 2 , 5 and 6'),
# ((1035, 1055), 'many QTL identified in the present study overlap with arthritis QTL previously identified , including loci 1 , 2 , 5 and 6 .'),
# ((1037, 1042), 'identified in the present study'),
# ((1042, 1043), 'overlap'),
# ((1044, 1048), 'arthritis QTL previously identified'),
# ((1044, 1055), 'arthritis QTL previously identified , including loci 1 , 2 , 5 and 6'),
# ((1046, 1048), 'previously identified'),
# ((1047, 1048), 'identified'),
# ((1048, 1055), 'including loci 1 , 2 , 5 and 6'),
# ((1049, 1055), 'loci 1 , 2 , 5 and 6'),
# ((1050, 1051), '1'),
# ((1051, 1052), '2'),
# ((1052, 1053), '5'),
# ((1054, 1055), '6'),
# ((1057, 1059), 'syntenic analysis'),
# ((1057, 1075), 'syntenic analysis revealed that the counterpart genomic regions on the human genome of many of these eight QTL'),
# ((1059, 1060), 'revealed'),
# ((1061, 1075), 'the counterpart genomic regions on the human genome of many of these eight QTL'),
# ((1066, 1069), 'the human genome'),
# ((1070, 1075), 'many of these eight QTL'),
# ((1076, 1077), 'linked'),
# ((1080, 1086), 'five of the eight small - effect QTL'),
# ((1080, 1089), 'five of the eight small - effect QTL the DBA / 1 alleles'),
# ((1080, 1093), 'five of the eight small - effect QTL the DBA / 1 alleles are the arthritis - enhancing alleles'),
# ((1086, 1089), 'the DBA / 1 alleles'),
# ((1087, 1089), 'DBA / 1 allele'),
# ((1087, 1089), 'DBA / 1 alleles'),
# ((1087, 1088), '1'),
# ((1089, 1090), 'are'),
# ((1090, 1093), 'the arthritis - enhancing alleles'),
# ((1091, 1092), 'arthritis - enhancing'),
# ((1094, 1097), 'the FVBN alleles'),
# ((1094, 1106), 'the FVBN alleles are the arthritis - enhancing alleles in the other three QTL'),
# ((1095, 1097), 'FVBN alleles'),
# ((1097, 1098), 'are'),
# ((1098, 1106), 'the arthritis - enhancing alleles in the other three QTL'),
# ((1102, 1106), 'the other three QTL'),
# ((1108, 1111), 'some susceptibility genes'),
# ((1108, 1113), 'some susceptibility genes could come'),
# ((1109, 1111), 'susceptibility genes'),
# ((1112, 1113), 'come'),
# ((1117, 1118), 'Interestingly'),
# ((1118, 1120), 'loci 2'),
# ((1118, 1137), 'loci 2 and 7 partially overlap with two arthritis - related QTL identified by us in the same F2 progeny [ 10 ]'),
# ((1119, 1120), '2'),
# ((1121, 1122), '7'),
# ((1123, 1124), 'overlap'),
# ((1125, 1137), 'two arthritis - related QTL identified by us in the same F2 progeny [ 10 ]'),
# ((1130, 1137), 'us in the same F2 progeny [ 10 ]'),
# ((1132, 1136), 'the same F2 pro'),
# ((1132, 1136), 'the same F2 progeny'),
# ((1132, 1137), 'the same F2 progeny [ 10 ]'),
# ((1134, 1135), 'F'),
# ((1134, 1136), 'F2 pro'),
# ((1136, 1137), '[ 10'),
# ((1136, 1137), '[ 10 ]'),
# ((1136, 1137), '10'),
# ((1137, 1139), 'Locus 2'),
# ((1139, 1141), 'was located'),
# ((1140, 1141), 'located'),
# ((1142, 1157), 'the same genomic region as Cia27 , a QTL controlling IgG2a antibody levels to collagen II'),
# ((1148, 1157), 'a QTL controlling IgG2a antibody levels to collagen II'),
# ((1151, 1152), 'IgG2a'),
# ((1151, 1153), 'IgG2a antibody'),
# ((1151, 1154), 'IgG2a antibody levels'),
# ((1151, 1155), 'IgG2a antibody levels to'),
# ((1151, 1157), 'IgG2a antibody levels to collagen II'),
# ((1155, 1157), 'collagen II'),
# ((1157, 1158), 'Recently'),
# ((1158, 1169), 'we have refined this QTL into a 4 . 1 Mb genomic region'),
# ((1161, 1169), 'this QTL into a 4 . 1 Mb genomic region'),
# ((1170, 1171), 'showed'),
# ((1172, 1180), 'a gene within this region regulates CIA severity'),
# ((1172, 1190), 'a gene within this region regulates CIA severity by controlling the IgG2a antibody levels to collagen II [ 31 ]'),
# ((1177, 1178), 'regulate'),
# ((1177, 1178), 'regulates'),
# ((1178, 1180), 'CIA severity'),
# ((1181, 1182), 'controlling'),
# ((1182, 1189), 'the IgG2a antibody levels to collagen II'),
# ((1182, 1190), 'the IgG2a antibody levels to collagen II [ 31 ]'),
# ((1183, 1184), 'IgG2a'),
# ((1183, 1185), 'IgG2a antibody'),
# ((1183, 1189), 'IgG2a antibody levels to collagen II'),
# ((1187, 1189), 'collagen II'),
# ((1189, 1190), '[ 31 ]'),
# ((1190, 1195), 'Locus 7 on chromosome 16'),
# ((1190, 1202), 'Locus 7 on chromosome 16 overlaps with Lp1 , which controls lymphocyte proliferation'),
# ((1195, 1196), 'overlap'),
# ((1195, 1196), 'overlaps'),
# ((1197, 1202), 'Lp1 , which controls lymphocyte proliferation'),
# ((1199, 1200), 'controls'),
# ((1200, 1202), 'lymphocyte proliferation'),
# ((1202, 1203), 'Furthermore'),
# ((1205, 1208), 'our unpublished data'),
# ((1205, 1220), 'our unpublished data , loci 8 on chromosome 17 controls lymphocyte adherence during development of CIA'),
# ((1208, 1213), 'loci 8 on chromosome 17'),
# ((1208, 1214), 'loci 8 on chromosome 17 controls'),
# ((1208, 1220), 'loci 8 on chromosome 17 controls lymphocyte adherence during development of CIA'),
# ((1209, 1213), '8 on chromosome 17'),
# ((1213, 1214), 'controls'),
# ((1214, 1216), 'lymphocyte adherence'),
# ((1214, 1220), 'lymphocyte adherence during development of CIA'),
# ((1215, 1216), 'adherence'),
# ((1217, 1218), 'development'),
# ((1217, 1220), 'development of CIA'),
# ((1220, 1221), 'Therefore'),
# ((1228, 1229), 'affect'),
# ((1229, 1231), 'CIA severity'),
# ((1232, 1233), 'controlling'),
# ((1232, 1235), 'controlling arthritis - related phenotypes'),
# ((1233, 1234), 'arthritis - related'),
# ((1233, 1235), 'arthritis - related phenotypes'),
# ((1233, 1234), 'related'),
# ((1235, 1237), 'Several studies'),
# ((1239, 1240), 'carried'),
# ((1239, 1241), 'carried out'),
# ((1239, 1257), 'carried out to detect gene expression during CIA , all of which used joints as the target tissue [ 15 , 16 , 21 , 22 ]'),
# ((1242, 1243), 'detect'),
# ((1242, 1245), 'detect gene expression'),
# ((1243, 1245), 'gene expression'),
# ((1246, 1257), 'CIA , all of which used joints as the target tissue [ 15 , 16 , 21 , 22 ]'),
# ((1247, 1250), 'all of which'),
# ((1247, 1251), 'all of which used'),
# ((1247, 1252), 'all of which used joints'),
# ((1247, 1256), 'all of which used joints as the target tissue'),
# ((1247, 1257), 'all of which used joints as the target tissue [ 15 , 16 , 21 , 22 ]'),
# ((1250, 1251), 'used'),
# ((1251, 1252), 'joints'),
# ((1253, 1256), 'the target tissue'),
# ((1256, 1257), '[ 15 , 16 , 21 , 22 ]'),
# ((1256, 1257), '15'),
# ((1256, 1257), '16'),
# ((1256, 1257), '21'),
# ((1256, 1257), '22'),
# ((1256, 1257), ']'),
# ((1257, 1259), 'This study'),
# ((1257, 1263), 'This study , for the first time ,'),
# ((1257, 1270), 'This study , for the first time , detected gene expression in LNs during CIA'),
# ((1257, 1270), 'This study , for the first time , detected gene expression in LNs during CIA .'),
# ((1257, 1270), 'This study , for the first time , detected gene expression in LNs during CIA . [SEP]'),
# ((1263, 1264), 'detected'),
# ((1263, 1270), 'detected gene expression in LNs during CIA'),
# ((1264, 1268), 'gene expression in LNs'),
# ((1264, 1270), 'gene expression in LNs during CIA'),
# ((1267, 1268), 'LN'),
# ((1267, 1268), 'LNs'),
# ((1270, 1272), 'We present'),
# ((1270, 1294), 'We present an extensive study of gene expression patterns in LNs of both genetically susceptible and resistant strains at four different phases of CIA'),
# ((1271, 1272), 'present'),
# ((1272, 1288), 'an extensive study of gene expression patterns in LNs of both genetically susceptible and resistant strains'),
# ((1272, 1294), 'an extensive study of gene expression patterns in LNs of both genetically susceptible and resistant strains at four different phases of CIA'),
# ((1276, 1288), 'gene expression patterns in LNs of both genetically susceptible and resistant strains'),
# ((1280, 1288), 'LNs of both genetically susceptible and resistant strains'),
# ((1283, 1284), 'genetically'),
# ((1283, 1285), 'genetically susceptible'),
# ((1284, 1285), 'susceptible'),
# ((1286, 1287), 'resistant'),
# ((1289, 1294), 'four different phases of CIA'),
# ((1297, 1300), 'differentially regulated genes'),
# ((1304, 1324), 'the PI and CA phases , and only a small number of genes were differentially expressed in two or three phases'),
# ((1310, 1316), 'only a small number of genes'),
# ((1317, 1319), 'differentially expressed'),
# ((1318, 1319), 'expressed'),
# ((1320, 1323), 'two or three'),
# ((1320, 1324), 'two or three phases'),
# ((1324, 1325), 'This'),
# ((1327, 1331), 'biological responses in LNs'),
# ((1330, 1331), 'LNs'),
# ((1334, 1344), 'the PI and CA phases than in the OA phase'),
# ((1334, 1350), 'the PI and CA phases than in the OA phase , and the responses at different phases'),
# ((1342, 1343), 'OA'),
# ((1345, 1350), 'the responses at different phases'),
# ((1354, 1360), 'the susceptible to the resistant strain'),
# ((1354, 1360), 'the susceptible to the resistant strain ,'),
# ((1354, 1374), 'the susceptible to the resistant strain , the biggest difference was found in one cluster of genes ( cluster IV , Figure 2 )'),
# ((1355, 1356), 'susceptible'),
# ((1357, 1360), 'the resistant strain'),
# ((1358, 1359), 'resistant'),
# ((1360, 1363), 'the biggest difference'),
# ((1360, 1374), 'the biggest difference was found in one cluster of genes ( cluster IV , Figure 2 )'),
# ((1364, 1365), 'found'),
# ((1366, 1370), 'one cluster of genes'),
# ((1369, 1370), 'genes'),
# ((1370, 1374), 'cluster IV , Figure 2'),
# ((1370, 1374), 'cluster IV , Figure 2 )'),
# ((1372, 1374), 'Figure 2'),
# ((1376, 1377), 'had'),
# ((1377, 1385), 'a higher expression in DBA / 1 than in FVB / N'),
# ((1377, 1395), 'a higher expression in DBA / 1 than in FVB / N at the early phases of CIA ( NC , PI and OA )'),
# ((1381, 1385), 'DBA / 1 than in FVB / N'),
# ((1386, 1395), 'the early phases of CIA ( NC , PI and OA )'),
# ((1390, 1395), 'CIA ( NC , PI and OA )'),
# ((1391, 1395), 'NC , PI and OA'),
# ((1391, 1395), 'NC , PI and OA )'),
# ((1396, 1400), 'the opposite expression pattern'),
# ((1401, 1404), 'the CA phase'),
# ((1404, 1407), 'GO term classification'),
# ((1404, 1418), 'GO term classification revealed that these genes were related to lymphocyte proliferation and activation'),
# ((1409, 1418), 'these genes were related to lymphocyte proliferation and activation'),
# ((1412, 1413), 'related'),
# ((1414, 1416), 'lymphocyte proliferation'),
# ((1414, 1418), 'lymphocyte proliferation and activation'),
# ((1420, 1425), 'lymphocytes in the DBA / 1 strain'),
# ((1420, 1428), 'lymphocytes in the DBA / 1 strain are more activated'),
# ((1420, 1434), 'lymphocytes in the DBA / 1 strain are more activated than those in the FVB / N strain'),
# ((1420, 1434), 'lymphocytes in the DBA / 1 strain are more activated than those in the FVB / N strain .'),
# ((1425, 1426), 'are'),
# ((1435, 1437), 'this difference'),
# ((1435, 1454), 'this difference is not CIA specific because the expression difference between the two strains existed in mice without immunisation'),
# ((1442, 1449), 'the expression difference between the two strains'),
# ((1442, 1454), 'the expression difference between the two strains existed in mice without immunisation'),
# ((1449, 1450), 'existed'),
# ((1449, 1454), 'existed in mice without immunisation'),
# ((1451, 1452), 'mice'),
# ((1451, 1454), 'mice without immunisation'),
# ((1453, 1454), 'immunisation'),
# ((1454, 1455), 'Additionally'),
# ((1455, 1462), 'some genes related to the immune response'),
# ((1455, 1476), 'some genes related to the immune response were upregulated in the DBA / 1 strain but not in the FVB / N strain during CIA'),
# ((1457, 1458), 'related'),
# ((1459, 1462), 'the immune response'),
# ((1463, 1464), 'upregulated'),
# ((1465, 1474), 'the DBA / 1 strain but not in the FVB / N strain'),
# ((1465, 1476), 'the DBA / 1 strain but not in the FVB / N strain during CIA'),
# ((1472, 1473), 'FVB / N'),
# ((1476, 1478), 'These differences'),
# ((1481, 1488), 'a higher antibody response to collagen II'),
# ((1481, 1498), 'a higher antibody response to collagen II occurred in the DBA / 1 strain compared to the FVB / N strain'),
# ((1486, 1488), 'collagen II'),
# ((1488, 1489), 'occurred'),
# ((1490, 1498), 'the DBA / 1 strain compared to the FVB / N strain'),
# ((1493, 1494), 'compared'),
# ((1502, 1509), 'the difference of the susceptibility to CIA'),
# ((1502, 1512), 'the difference of the susceptibility to CIA between both strains'),
# ((1502, 1512), 'the difference of the susceptibility to CIA between both strains .'),
# ((1505, 1509), 'the susceptibility to CIA'),
# ((1514, 1516), 'were identified'),
# ((1514, 1539), 'were identified as potential candidate genes for six of the eight small - effect QTL according to their gene expression patterns during CIA and their genomic locations'),
# ((1515, 1516), 'identified'),
# ((1517, 1539), 'potential candidate genes for six of the eight small - effect QTL according to their gene expression patterns during CIA and their genomic locations'),
# ((1521, 1527), 'six of the eight small - effect QTL'),
# ((1521, 1539), 'six of the eight small - effect QTL according to their gene expression patterns during CIA and their genomic locations'),
# ((1529, 1535), 'their gene expression patterns during CIA'),
# ((1529, 1539), 'their gene expression patterns during CIA and their genomic locations'),
# ((1536, 1539), 'their genomic locations'),
# ((1543, 1544), 'located'),
# ((1545, 1561), 'QTL 4 and 7 , suggesting that QTG polymorphisms of the susceptibility genes inside these two QTL'),
# ((1546, 1547), '4'),
# ((1548, 1549), '7'),
# ((1551, 1561), 'QTG polymorphisms of the susceptibility genes inside these two QTL'),
# ((1554, 1561), 'the susceptibility genes inside these two QTL'),
# ((1564, 1566), 'the phenotype'),
# ((1567, 1568), 'regulating'),
# ((1568, 1570), 'gene expression'),
# ((1570, 1576), 'Two of the 21 candidate genes'),
# ((1570, 1583), 'Two of the 21 candidate genes were reported to be involved in arthritis'),
# ((1572, 1576), 'the 21 candidate genes'),
# ((1577, 1578), 'reported'),
# ((1583, 1599), 'Mapk14 , a candidate gene for locus 8 and also called p38 mitogen - activated protein kinase ( MAPK ) alpha ,'),
# ((1588, 1590), 'locus 8'),
# ((1588, 1599), 'locus 8 and also called p38 mitogen - activated protein kinase ( MAPK ) alpha'),
# ((1588, 1599), 'locus 8 and also called p38 mitogen - activated protein kinase ( MAPK ) alpha ,'),
# ((1593, 1599), 'p38 mitogen - activated protein kinase ( MAPK ) alpha'),
# ((1599, 1600), 'regulate'),
# ((1599, 1600), 'regulates'),
# ((1603, 1604), 'arthritis'),
# ((1603, 1605), 'arthritis - essential cytokines'),
# ((1603, 1612), 'arthritis - essential cytokines , such as tumour necrosis factor and interleukin - 1'),
# ((1603, 1613), 'arthritis - essential cytokines , such as tumour necrosis factor and interleukin - 1 [ 32 ]'),
# ((1607, 1610), 'tumour necrosis factor'),
# ((1607, 1612), 'tumour necrosis factor and interleukin - 1'),
# ((1611, 1612), 'interleukin - 1'),
# ((1616, 1624), 'p38 MAPK could attenuate CIA in rats [ 33 ]'),
# ((1619, 1620), 'attenuate'),
# ((1620, 1623), 'CIA in rats'),
# ((1620, 1624), 'CIA in rats [ 33 ]'),
# ((1622, 1623), 'rats'),
# ((1625, 1636), 'p38 MAPK is becoming a potential therapeutic target in RA [ 32 ]'),
# ((1634, 1636), 'RA [ 32 ]'),
# ((1636, 1643), 'Stat5a , a candidate gene for loci 6'),
# ((1636, 1653), 'Stat5a , a candidate gene for loci 6 , is an essential molecule for lymphoid development and differentiation [ 34 ]'),
# ((1637, 1643), 'a candidate gene for loci 6'),
# ((1641, 1643), 'loci 6'),
# ((1642, 1643), '6'),
# ((1643, 1644), 'is'),
# ((1644, 1652), 'an essential molecule for lymphoid development and differentiation'),
# ((1648, 1652), 'lymphoid development and differentiation'),
# ((1653, 1654), 'Stat5a - deficient'),
# ((1653, 1655), 'Stat5a - deficient mice'),
# ((1653, 1667), 'Stat5a - deficient mice were reported to lose tolerance , resulting in the development of autoimmune diseases'),
# ((1656, 1657), 'reported'),
# ((1658, 1659), 'lose'),
# ((1665, 1667), 'autoimmune diseases'),
# ((1667, 1684), 'Stat5a is suggested to contribute to tolerance through maintenance of the CD4 + CD25 + regulatory T cell population [ 35 ]'),
# ((1668, 1669), 'is'),
# ((1669, 1670), 'suggested'),
# ((1671, 1672), 'contribute'),
# ((1673, 1674), 'tolerance'),
# ((1675, 1684), 'maintenance of the CD4 + CD25 + regulatory T cell population [ 35 ]'),
# ((1677, 1683), 'the CD4 + CD25 + regulatory T cell population'),
# ((1677, 1684), 'the CD4 + CD25 + regulatory T cell population [ 35 ]'),
# ((1684, 1685), 'Therefore'),
# ((1685, 1687), 'we have'),
# ((1685, 1688), 'we have presented'),
# ((1685, 1702), 'we have presented a strategy to identify small - effect QTL and search for potential candidate genes within them .'),
# ((1687, 1688), 'presented'),
# ((1688, 1694), 'a strategy to identify small - effect QTL'),
# ((1688, 1702), 'a strategy to identify small - effect QTL and search for potential candidate genes within them'),
# ((1688, 1702), 'a strategy to identify small - effect QTL and search for potential candidate genes within them .'),
# ((1691, 1692), 'identify'),
# ((1691, 1694), 'identify small - effect QTL'),
# ((1695, 1696), 'search'),
# ((1703, 1718), 'it is noteworthy that the low statistical threshold and small number of animals per group'),
# ((1703, 1720), 'it is noteworthy that the low statistical threshold and small number of animals per group could lead'),
# ((1707, 1711), 'the low statistical threshold'),
# ((1707, 1718), 'the low statistical threshold and small number of animals per group'),
# ((1709, 1711), 'statistical threshold'),
# ((1712, 1718), 'small number of animals per group'),
# ((1715, 1716), 'animals'),
# ((1717, 1718), 'group'),
# ((1718, 1720), 'could lead'),
# ((1719, 1720), 'lead'),
# ((1726, 1729), 'the genome level'),
# ((1729, 1745), 'some of the eight small - effect QTL identified using a very low threshold value ( P < 0 . 05 )'),
# ((1729, 1747), 'some of the eight small - effect QTL identified using a very low threshold value ( P < 0 . 05 ) could be'),
# ((1735, 1736), 'identified'),
# ((1737, 1745), 'a very low threshold value ( P < 0 . 05 )'),
# ((1745, 1746), 'could'),
# ((1745, 1747), 'could be'),
# ((1746, 1747), 'be'),
# ((1749, 1770), 'For example , locus 4 was identified with a low P value and does not overlap with any previously identified arthritis QTL . [SEP]'),
# ((1751, 1753), 'locus 4'),
# ((1751, 1770), 'locus 4 was identified with a low P value and does not overlap with any previously identified arthritis QTL'),
# ((1751, 1770), 'locus 4 was identified with a low P value and does not overlap with any previously identified arthritis QTL .'),
# ((1751, 1770), 'locus 4 was identified with a low P value and does not overlap with any previously identified arthritis QTL . [SEP]'),
# ((1754, 1755), 'identified'),
# ((1756, 1760), 'a low P value'),
# ((1756, 1770), 'a low P value and does not overlap with any previously identified arthritis QTL'),
# ((1768, 1770), 'arthritis QTL'),
# ((1773, 1774), ','),
# ((1774, 1781), 'the small number of animals per group'),
# ((1774, 1790), 'the small number of animals per group and the low threshold used to detect gene expression'),
# ((1774, 1801), 'the small number of animals per group and the low threshold used to detect gene expression could also result in false positives in the differentially expressed genes'),
# ((1780, 1781), 'group'),
# ((1782, 1790), 'the low threshold used to detect gene expression'),
# ((1792, 1793), 'result'),
# ((1797, 1801), 'the differentially expressed genes'),
# ((1801, 1802), 'Furthermore'),
# ((1802, 1808), 'the differential expression of a gene'),
# ((1802, 1823), 'the differential expression of a gene could result not only from allele difference between two strains , but also from other factors .'),
# ((1806, 1808), 'a gene'),
# ((1809, 1810), 'result'),
# ((1813, 1818), 'allele difference between two strains'),
# ((1813, 1823), 'allele difference between two strains , but also from other factors'),
# ((1813, 1823), 'allele difference between two strains , but also from other factors .'),
# ((1824, 1826), 'our findings'),
# ((1830, 1832), 'future studies'),
# ((1832, 1833), 'Conclusion'),
# ((1833, 1835), 'We present'),
# ((1833, 1844), 'We present a strategy to search candidate genes for small - effect QTL'),
# ((1834, 1835), 'present'),
# ((1838, 1839), 'search'),
# ((1842, 1844), 'small - effect QTL'),
# ((1845, 1859), 'this strategy , we identified 21 candidate genes for 8 small - effect QTL regulating CIA susceptibility'),
# ((1847, 1849), 'we identified'),
# ((1847, 1859), 'we identified 21 candidate genes for 8 small - effect QTL regulating CIA susceptibility'),
# ((1848, 1849), 'identified'),
# ((1849, 1859), '21 candidate genes for 8 small - effect QTL regulating CIA susceptibility'),
# ((1853, 1859), '8 small - effect QTL regulating CIA susceptibility'),
# ((1857, 1859), 'CIA susceptibility'),
# ((1859, 1862), 'Our future studies'),
# ((1859, 1869), 'Our future studies will be carried out using two approaches'),
# ((1867, 1869), 'two approaches'),
# ((1869, 1871), 'The first'),
# ((1873, 1891), 'congenic animals for promising small - effect QTL that have relatively high P values and overlap with previously - identified arthritis QTL'),
# ((1873, 1891), 'congenic animals for promising small - effect QTL that have relatively high P values and overlap with previously - identified arthritis QTL .'),
# ((1876, 1879), 'promising small - effect QTL'),
# ((1876, 1891), 'promising small - effect QTL that have relatively high P values and overlap with previously - identified arthritis QTL'),
# ((1888, 1891), 'previously - identified arthritis QTL'),
# ((1889, 1891), 'arthritis QTL'),
# ((1891, 1894), 'The second approach'),
# ((1891, 1904), 'The second approach is investigating candidate genes using both mouse and human studies'),
# ((1895, 1896), 'investigating'),
# ((1896, 1898), 'candidate genes'),
# ((1899, 1904), 'both mouse and human studies'),
# ((1900, 1901), 'mouse'),
# ((1904, 1919), 'Candidate genes will be selected according to their function and polymorphism between the two strains'),
# ((1908, 1909), 'selected'),
# ((1911, 1919), 'their function and polymorphism between the two strains'),
# ((1919, 1920), 'Thereafter'),
# ((1920, 1923), 'we will generate'),
# ((1920, 1934), 'we will generate knock - out mice to investigate the role of the genes in CIA'),
# ((1922, 1923), 'generate'),
# ((1927, 1934), 'the role of the genes in CIA'),
# ((1930, 1934), 'the genes in CIA'),
# ((1935, 1947), 'the loci whose counterparts on the human genome are linked to RA'),
# ((1940, 1943), 'the human genome'),
# ((1944, 1945), 'linked'),
# ((1947, 1950), 'we will investigate'),
# ((1947, 1960), 'we will investigate the candidate genes using case - control association studies in RA cohorts'),
# ((1949, 1950), 'investigate'),
# ((1950, 1953), 'the candidate genes'),
# ((1950, 1960), 'the candidate genes using case - control association studies in RA cohorts'),
# ((1954, 1960), 'case - control association studies in RA cohorts'),
# ((1958, 1960), 'RA cohorts'),
# ((1960, 1961), 'Abbreviations'),
# ((1961, 1962), 'CA'),
# ((1961, 1965), 'CA = chronic arthritis'),
# ((1961, 1974), 'CA = chronic arthritis ; CIA = collagen - induced arthritis ; CV = coefficiant of variation'),
# ((1963, 1965), 'chronic arthritis'),
# ((1967, 1969), 'collagen - induced arthritis'),
# ((1967, 1974), 'collagen - induced arthritis ; CV = coefficiant of variation'),
# ((1969, 1974), 'CV = coefficiant of variation'),
# ((1971, 1974), 'coefficiant of variation'),
# ((1974, 1978), 'GO = Gene Ontology'),
# ((1976, 1978), 'Gene Ontology'),
# ((1980, 1982), 'lymph node'),
# ((1982, 1983), 'LOD'),
# ((1984, 1988), 'logarithm of the odds'),
# ((1988, 1989), 'MAPK'),
# ((1988, 1997), 'MAPK = mitogen - activated protein kinase ; NC = naive control'),
# ((1988, 2002), 'MAPK = mitogen - activated protein kinase ; NC = naive control ; OA = onset of arthritis'),
# ((1990, 1993), 'mitogen - activated protein kinase'),
# ((1993, 1994), 'NC'),
# ((1995, 1997), 'naive control'),
# ((2004, 2005), 'post - immunisation'),
# ((2007, 2010), 'quantitative trait gene'),
# ((2007, 2021), 'quantitative trait gene ; QTL = quantitative trait loci ; RA = rheumatoid arthritis . Competing interests [SEP]'),
# ((2010, 2011), 'QTL'),
# ((2010, 2015), 'QTL = quantitative trait loci'),
# ((2010, 2021), 'QTL = quantitative trait loci ; RA = rheumatoid arthritis . Competing interests [SEP]'),
# ((2012, 2015), 'quantitative trait loci'),
# ((2015, 2021), 'RA = rheumatoid arthritis . Competing interests [SEP]'),
# ((2017, 2019), 'rheumatoid arthritis'),
# ((2017, 2019), 'rheumatoid arthritis .'),
# ((2017, 2021), 'rheumatoid arthritis . Competing interests [SEP]'),
# ((2019, 2021), 'Competing interests'),

# %%
# !zip -r /content/out.zip /content/coref/data/out
# Out:
#   adding: content/coref/data/out/ (stored 0%)
#   adding: content/coref/data/out/17696610_3.json (deflated 84%)
#   adding: content/coref/data/out/17244351_1.json (deflated 83%)
#   adding: content/coref/data/out/17590087_0.json (deflated 82%)
#   adding: content/coref/data/out/17590087_2.json (deflated 83%)
#   adding: content/coref/data/out/17608565_1.json (deflated 83%)
#   adding: content/coref/data/out/17425782_2.json (deflated 83%)
#   adding: content/coref/data/out/17244351_0.json (deflated 82%)
#   adding: content/coref/data/out/17194222_1.json (deflated 83%)
#   adding: content/coref/data/out/17447844_2.json (deflated 83%)
#   adding: content/coref/data/out/17425782_0.json (deflated 82%)
#   adding: content/coref/data/out/17194222_2.json (deflated 83%)
#   adding: content/coref/data/out/17425782_4.json (deflated 85%)
#   adding: content/coref/data/out/17696610_1.json (deflated 83%)
#   adding: content/coref/data/out/17608565_0.json (deflated 82%)
#   adding: content/coref/data/out/17590087_4.json (deflated 85%)
#   adding: content/coref/data/out/17194222_3.json (deflated 84%)
#   adding: content/coref/data/out/17244351_4.json (deflated 85%)
#   adding: content/coref/data/out/17696610_4.json (deflated 85%)
#   adding: content/coref/data/out/17608565_3.json (deflated 84%)
#   adding: content/coref/data/out/17590087_1.json (deflated 83%)
#   adding: content/coref/data/out/17447844_3.json (deflated 84%)
#   adding: content/coref/data/out/17696610_0.json (deflated 82%)
#   adding: content/coref/data/out/17608565_4.json (deflated 85%)
#   adding: content/coref/data/out/17425782_3.json (deflated 84%)
#   adding: content/coref/data/out/17590087_3.json (deflated 84%)
#   adding: content/coref/data/out/17244351_2.json (deflated 83%)
#   adding: content/coref/data/out/17447844_0.json (deflated 82%)
#   adding: content/coref/data/out/17447844_4.json (deflated 85%)
#   adding: content/coref/data/out/17608565_2.json (deflated 83%)
#   adding: content/coref/data/out/17425782_1.json (deflated 83%)
#   adding: content/coref/data/out/17244351_3.json (deflated 84%)
#   adding: content/coref/data/out/17447844_1.json (deflated 83%)
#   adding: content/coref/data/out/17194222_0.json (deflated 82%)
#   adding: content/coref/data/out/17696610_2.json (deflated 83%)
#   adding: content/coref/data/out/17194222_4.json (deflated 85%)

# %%
files.download("/content/out.zip")
